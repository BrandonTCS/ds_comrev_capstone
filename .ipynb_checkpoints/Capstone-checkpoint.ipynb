# %% [markdown]
# ## NLP with company reviews on Glassdoor
#
# This capstone project is about helping companies/potential employee identify potential problems within a company. The business focus will be to help potential clients/companies get insights into the problems that existing or past employees faced within the company to reduce the turnover rate, solve potential mental health issues of employees and improve the image of the company. This could also assist the ministry of manpower or ministry with complaints filed by employees on employers for misconduct on determining if such issues has been flagged by other employees of the companies. These are just some of the use case of this project but not just limited to only the use case mentioned above.

# %% [markdown]
# #### Credit to Mathew Chatham for the scraper
# This is to credit Matthew Chatham for the scraper in which he had created and shared on github. The scraper could not work immediately as the codes on glassdoor has changed over the time of 2 -3 years which he created the scraper. Some tweaks was done to update and remove fields that are not required. The link can be found here (https://github.com/MatthewChatham/glassdoor-review-scraper)

# %%
import selenium
import pandas
import re
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
import seaborn as sns

# %% [markdown]
# ## Data Extraction
#
# ### Using the scraper to obtain the data and putting it into a DataFrame

# %%
# using the code by Matthew after some updates was done to get the scraper to work

# this is to scrape 500 reviews from glassdoor of Tencent a china internet company
# %run main.py --url "https://www.glassdoor.sg/Reviews/Tencent-Reviews-E38281.htm" --limit 500 -f tencent_reviews.csv

# %%
# this is to scrape 500 reviews from glassdoor of Google a US internet company
# %run main.py --url "https://www.glassdoor.sg/Reviews/Google-Reviews-E9079.htm" --limit 500 -f google_reviews.csv

# %%
# reading the csv file and assign the data to a variable in a dataframe
tencent_df = pandas.read_csv('tencent_reviews.csv')
google_df = pandas.read_csv('google_reviews.csv')

# %%
tencent_df.sample(20)
# Out:
#                            employee_title             location  \
# 406                             Anonymous     Beijing, Beijing
# 283                     Software Engineer  Shenzhen, Guangdong
# 42                              Anonymous                  NaN
# 134                             Marketing                  NaN
# 237   Senior Business Development Manager              Bangkok
# 494                             Anonymous     Beijing, Beijing
# 404                       Project Manager        Palo Alto, CA
# 333                       Game Operations  Shenzhen, Guangdong
# 27                       Senior Recruiter            Singapore
# 452                     Software Engineer  Shenzhen, Guangdong
# 129                     Software Engineer  Shenzhen, Guangdong
# 261                       Product Manager                  NaN
# 273                          Data Analyst  Shenzhen, Guangdong
# 246              User Experience Designer  Shenzhen, Guangdong
# 3                                 Manager                  NaN
# 256                    Software Developer          Burnaby, BC
# 341                       Project Manager                  NaN
# 241                             Anonymous                  NaN
# 289                      Gaming Associate            Hong Kong
# 142                 Operations Specialist                  NaN
#
#     employee_status                                       review_title  \
# 406    18 Apr 2021                              Best employer in China
# 283     3 Nov 2021                                       goose company
# 42     21 Aug 2017                         good environment and people
# 134    10 Mar 2022                                    Great experience
# 237    28 Nov 2021                           4 years+ at Tencent Games
# 494    23 Dec 2020                                               power
# 404    28 Apr 2021   Will not recommend unless desperate for visa s...
# 333    18 Aug 2021                        stuck in China, bad beauracy
# 27     29 Jul 2021   The Chinese Tech Company that cares for it's e...
# 452     1 Mar 2021                                                Nice
# 129    29 Mar 2022                                  overall evaluation
# 261    22 Oct 2021                                  Overall impression
# 273    12 Oct 2021                                                Good
# 246     4 Nov 2021                     junior user experience designer
# 3      27 Apr 2022                          Toss you away like garbage
# 256    23 Oct 2021                                               Top 2
# 341    19 Jul 2021                                     Project Manager
# 241    10 Nov 2021                                             Manager
# 289     8 Oct 2021                                          nice place
# 142    13 Mar 2022                                           treatment
#
#                                                   pros  \
# 406  Great facility and benefits. We have a gym, ba...
# 283                          no pros to this company\n
# 42   good salary, very stable platform to try what ...
# 134  Great experience, friendly and dynamic environ...
# 237  Flexible culture and support learning on the j...
# 494                very nice very friendly and so on\n
# 404  stable paychecks and benefit, Tencent will not...
# 333  less pressure\n- less than bytedance\n\nnice b...
# 27   - great company values and indeed they practic...
# 452  Free gym and breakfast/dinner, nice environment\n
# 129  flexible working hours, benifits.\nWLB when co...
# 261  Very reason policy and organization, Very good...
# 273              Great company, good culture overall\n
# 246  1.the most huge Internet service company in Ch...
# 3    Good benefits (comparing to their Chinese coun...
# 256  1. The system is more humane\n2. High industry...
# 341     nice environment, good pay and good platform\n
# 241  Give lots of flexibility/trust to employees\nR...
# 289  everything, I really like the job and would li...
# 142  Perfect welfare system.\nFlexible working hour...
#
#                                                   cons  rating_overall
# 406  frequent organizational changes\nslow decision...             5.0
# 283  too much work time\npushy leader\nBe the first...             1.0
# 42   too stable, the organization is becoming less ...             5.0
# 134  I don't find any cons\nBe the first to find th...             5.0
# 237  Unorganized work approach and a little hard to...             4.0
# 494  too people too tield too full time\nBe the fir...             5.0
# 404  - Poor WLB, a lot of political games, culture ...             2.0
# 333  stuck in China\n- stuck into a stable stage as...             4.0
# 27   - too bad we can't really work in office and m...             5.0
# 452  the work time is longer than expected\nBe the ...             5.0
# 129  Frequent reorg of non-core businesses, PIP.\nB...             4.0
# 261  almost no cons, too much thing can be learnt i...             5.0
# 273  not at the moment .\nBe the first to find this...             5.0
# 246  I don't know what cons about this company .\nB...             5.0
# 3    CFO said there won’t be layoffs during industr...             2.0
# 256  Difficulties in inter-departmental cooperation...             5.0
# 341  not flexible enough, individual future growth\...             5.0
# 241  late meeting in the evening due to time zone d...             5.0
# 289  nothing, so far a good place to work\nBe the f...             4.0
# 142  longer working hours and difficulty in promoti...             3.0

# %%
google_df.sample(20)
# Out:
#                                  employee_title               location  \
# 416                People Operations Specialist              Singapore
# 273                                   Anonymous                    NaN
# 251                             Human Resources                    NaN
# 214                          Software Developer              Singapore
# 117                                   Recruiter                    NaN
# 357                             Systems Analyst              Singapore
# 341                                   Anonymous                    NaN
# 355                               Sales Manager              Singapore
# 126                        Marketing Specialist              Singapore
# 158                                       Sales                    NaN
# 267                                   Anonymous                    NaN
# 459                             Program Manager      Mountain View, CA
# 253                     Associate Staffing Lead              Singapore
# 94                                    Anonymous              Singapore
# 321   Senior Security Specialist At Data Center  Jurong West New Town,
# 415                           Account Executive              Singapore
# 133                 Inside Sales Representative              Singapore
# 244                      Engineering Executive               Singapore
# 433                                   Anonymous              Singapore
# 491                          Software Developer                    NaN
#
#     employee_status                                       review_title  \
# 416   25 Sept 2016                            HR Operations Specialist
# 273     6 Dec 2020                                            Benefits
# 251    12 Jan 2021                                     Awesome company
# 214    30 Mar 2021                                        Best to work
# 117    25 Aug 2021                                             Love it
# 357     7 Aug 2019                                       Great Company
# 341    27 Jan 2020                           Product Marketing Manager
# 355    26 Aug 2019                         GMT Digital - my dream team
# 126     4 Aug 2021                                               Great
# 158    16 Jun 2021                                                Good
# 267     5 Jan 2021                                      Nice workplace
# 459    21 Jun 2013   Moving at the speed of light, burn out is inev...
# 253    14 Jan 2021                                               Great
# 94     25 Oct 2021                        Good place for career growth
# 321    25 Jun 2020   It is what not the hype you read in the news. ...
# 415     1 Jan 2017                                     Account Manager
# 133    25 Jul 2021                                        Inside sales
# 244    25 Jan 2021                                                best
# 433    29 Aug 2015               So many complacent, untalented people
# 491    18 May 2022                   I conclude that work is necessary
#
#                                                   pros  \
# 416  Competitive compensation, great perks, flexibi...
# 273                  Best in class medical insurance\n
# 251       Great culture, smart people, good benefits\n
# 214  flexible working\ngood working environment\nth...
# 117           Flexibility, perks, comp, people, food\n
# 357              Everything is perfect. No problems.\n
# 341      Great people, exciting and challenging work\n
# 355  Clear goals, on-time salary, compensations, fr...
# 126  Great work culture and a high performing team ...
# 158                         Good goos good good good\n
# 267                   Nice workplace and nice office\n
# 459  1) Food, food, food. 15+ cafes on main campus ...
# 253      Flexibility, growth and impact in the world\n
# 94   Good benefits. Great culture. Working with a b...
# 321                                  B E N E F I T S\n
# 415          New job challenges and glassdoor office\n
# 133  Great company with amazing perks and an awesom...
# 244             very conducice environent to work in\n
# 433             Good work culture, free food, travel\n
# 491                         i like it for glass door\n
#
#                                                   cons  rating_overall
# 416  Becoming really big and hence unavoidable bure...             4.0
# 273  Lack of work life balance\nBe the first to fin...             5.0
# 251  High performance environment, stressful, compe...             5.0
# 214  Potentially long durations between promotions....             4.0
# 117  Long hours, ambiguity, average managers\nBe th...             5.0
# 357  Nothing to share here. Great company.\nBe the ...             5.0
# 341  Not very structured and strategies evolve all ...             4.0
# 355  small space, old-fashioned design, strong requ...             5.0
# 126  Cross-functional management is a must, otherwi...             5.0
# 158  Bad bad bad bad bad\nAdvice to Management\nGoo...             3.0
# 267  Office quite far to the West.\nBe the first to...             4.0
# 459  1) Work/life balance. What balance? All those ...             4.0
# 253  Ambiguity, constant change, competitive salary...             5.0
# 94   It's very competitive and takes time to be pro...             5.0
# 321  Global MNC but still local mentality with horr...             1.0
# 415  Free lunch and snack and other benefits\nBe th...             5.0
# 133  Nothing specific i can say at this point in ti...             5.0
# 244  very high standards...hard to compete with sun...             5.0
# 433  This mentality that Google is the place to "en...             3.0
# 491  yes i'am happy for working\nAdvice to Manageme...             5.0

# %% [markdown]
# ## Data Preprocessing
#
# ### Creating a helper function to clean the text for title, pros and cons

# %%
# helper function to clean the data for pros

def clean_text_pros(text):
    # remove "/n"
    pattern1 = re.compile(r'\n')
    text = pattern1.sub(r'',text)
    # remove irrelevant character such as numbers and punctutation
    pattern2 = re.compile(r'[^a-zA-Z0-9]')
    text = pattern2.sub(r' ',text)
    # remove extra whitespaces
    pattern3 = re.compile(r'^\s*|\s\s*')
    text = pattern3.sub(r' ', text).strip()
    # text to all lower case
    text = text.lower()
    
    return text

# helper function to clean the data for cons

def clean_text_cons(text):
    # remove the text that is not part of the actual comments
    pattern1 = re.compile(r'\nBe\sthe\sfirst.+')
    text = pattern1.sub(r'',text)
    pattern2 = re.compile(r'\d\speople\sfound\sthis.+')
    text = pattern2.sub(r'',text)
    pattern3 = re.compile(r'\d\sperson\sfound.+')
    text = pattern3.sub(r'',text)
    pattern4 = re.compile(r'\nHelpful\nShare\nRepor')
    text = pattern4.sub(r'',text)
    
    # remove "/n"
    pattern5 = re.compile(r'\n')
    text = pattern5.sub(r'',text)
    # remove irrelevant character such as numbers and punctuation
    pattern6 = re.compile(r'[^a-zA-Z0-9]')
    text = pattern6.sub(r' ',text)
    # remove extra whitespaces
    pattern7= re.compile(r'^\s*|\s\s*')
    text = pattern7.sub(r' ', text).strip()
    # text to all lower case
    text = text.lower()
    
    return text

def clean_title(text):
    # remove "/n"
    pattern1 = re.compile(r'\n')
    text = pattern1.sub(r'',text)
    # remove irrelevant character such as numbers and punctutation
    pattern2 = re.compile(r'[^a-zA-Z0-9]')
    text = pattern2.sub(r' ',text)
    # remove extra whitespaces
    pattern3 = re.compile(r'^\s*|\s\s*')
    text = pattern3.sub(r' ', text).strip()
    # text to all lower case
    text = text.lower()
    
    return text

# %%
# running the helper function to clean both google and tencent dataset

tencent_df['pros'] = tencent_df['pros'].map(lambda x: clean_text_pros(str(x)))
tencent_df['cons'] = tencent_df['cons'].map(lambda x: clean_text_cons(x))
tencent_df['review_title'] = tencent_df['review_title'].map(lambda x: clean_title(str(x)))
google_df['pros'] = google_df['pros'].map(lambda x: clean_text_pros(str(x)))
google_df['cons'] = google_df['cons'].map(lambda x: clean_text_cons(x))
google_df['review_title'] = google_df['review_title'].map(lambda x: clean_title(str(x)))

# %%
tencent_df.sample(30)
# Out:
#                         employee_title             location employee_status  \
# 465                  Software Engineer  Shenzhen, Guangdong    19 Feb 2021
# 273                       Data Analyst  Shenzhen, Guangdong    12 Oct 2021
# 252                      Game Designer  Shenzhen, Guangdong    11 Nov 2021
# 58                  Operations Manager                  NaN    14 May 2022
# 163         Product Operations Analyst  Shenzhen, Guangdong     9 Feb 2022
# 57                  WeChat Pay Manager                  NaN    14 May 2022
# 416   Tencent Cloud Product Experience  Shenzhen, Guangdong    24 Apr 2021
# 220                     Data Scientist  Shenzhen, Guangdong    24 Dec 2021
# 167                  ProductionManager     Beijing, Beijing    22 Feb 2022
# 131                      Game Designer                  NaN    27 Mar 2022
# 283                  Software Engineer  Shenzhen, Guangdong     3 Nov 2021
# 349                   Strategy Manager   Shanghai, Shanghai    13 Jul 2021
# 229                           Director   Shanghai, Shanghai    13 Dec 2021
# 187                         Internship                  NaN    17 Jan 2022
# 16                            Engineer                  NaN     6 Feb 2022
# 123                          Anonymous                  NaN    20 Mar 2022
# 104                  Global Operations  Shenzhen, Guangdong    31 Mar 2022
# 348                    Product Manager                  NaN    29 Jun 2021
# 194                     Data Scientist  Shenzhen, Guangdong    22 Jan 2022
# 288                 Applied Researcher  Shenzhen, Guangdong   24 Sept 2021
# 309             Senior Product Manager            Hong Kong   20 Sept 2021
# 173                      Brand Manager                  NaN    14 Feb 2022
# 399                  Software Engineer  Shenzhen, Guangdong    12 May 2021
# 304                   Mobile Developer  Shenzhen, Guangdong    8 Sept 2021
# 386                    Product Manager  Shenzhen, Guangdong    23 May 2021
# 204            Business Analyst Intern  Shenzhen, Guangdong    20 Jan 2022
# 280         Financial Business Partner     Beijing, Beijing    14 Oct 2021
# 480                        Team Leader  Shenzhen, Guangdong     9 Jan 2021
# 4                        Senior Artist                  NaN     8 Apr 2022
# 32                   Software Engineer                  NaN    14 May 2021
#
#                                           review_title  \
# 465                                       overall good
# 273                                               good
# 252                           tencent timi j6 workshop
# 58                        good benefits bad management
# 163                                           new grad
# 57                                tiring but rewarding
# 416                                       offer report
# 220  being nice to employees situation varies betwe...
# 167                                               good
# 131                                            tencent
# 283                                      goose company
# 349                                 good place overall
# 229                                               good
# 187                                                nan
# 16                    good company but long working hr
# 123                                good place for work
# 104  chinese tech giant on the way to become a glob...
# 348                                    tencent is good
# 194                                       infras sucks
# 288                                             ai lab
# 309                             senior product manager
# 173                    great to join at a senior level
# 399                                    a great company
# 304                                           good job
# 386  probably best culture among all tech companies...
# 204                                          ba intern
# 280                          pros and cons for tencent
# 480                                               good
# 4             tencent is the dream from my younger age
# 32                                    not bad but push
#
#                                                   pros  \
# 465                1 good administrative2 little perks
# 273                 great company good culture overall
# 252  very complete working pipeline and business lo...
# 58   its a good company with good benefits and a lo...
# 163               good company good team good exposure
# 57   good team spirit can understand market develop...
# 416                   good name and good money i think
# 220  relative high salary provides relatively good ...
# 167              ten cent gives good food during lunch
# 131  benefits are decent it s a huge company with r...
# 283                            no pros to this company
# 349                 decent package great employee care
# 229                      overall good payment in china
# 187        provide great opportunities for new joiners
# 16               friendly culture and smart colleagues
# 123  1 good employee benefits 2 good business resou...
# 104  startup mindset flat teams nice mix of china i...
# 348          excellent environment and people is great
# 194                           10 am 8 pm 5 days a week
# 288  in ai lab the environment feels soft and comfo...
# 309  dynamic environment good for those looking for...
# 173            wide portfolio of products to look over
# 399        innovation relax strong cooperation ability
# 304             free culture good policy good colleges
# 386  open culture young colleagues decent compensat...
# 204  good exposure and nice supervisor as well as w...
# 280     big brandfast growthexcellent incentiveand etc
# 480                             good job and relax job
# 4    resource tech support good income have it s ow...
# 32                not bad nice welfare and nice salary
#
#                                                   cons  rating_overall
# 465  1 some teams have pua leader2 only several ieg...             4.0
# 273                                  not at the moment             5.0
# 252   late finish time almost over my job 9pm each day             4.0
# 58   main issue lies in the director level manageme...             4.0
# 163  relative low comp long hoursttencent responset...             5.0
# 57   high workload a lot of presentations managemen...             4.0
# 416            innovation is behind alibaba and huawei             4.0
# 220  overtime working is very common in some depart...             4.0
# 167  no youtube or google or instagramadvice to man...             3.0
# 131  the structure of the company can get very comp...             4.0
# 283                     too much work timepushy leader             1.0
# 349  inefficiency in infrastructure and toolingadvi...             4.0
# 229  long hours with complicated communication proc...             4.0
# 187                         couldn t think of any cons             5.0
# 16   prepare to have a lot of hard work and long wo...             4.0
# 123  1 not international enough 2 housing price in ...             5.0
# 104  most of the culture is quite china centric but...             5.0
# 348                  nothing i can think of it s great             5.0
# 194  infras sucks no guidance no senior ds guide yo...             4.0
# 288        different department have different culture             5.0
# 309  lots of organization changes lots of internal ...             3.0
# 173  difficult to work as a foreigner unless you sp...             3.0
# 399  too much work too much overtimeadvice to manag...             4.0
# 304  unstable project don t like the drink culture ...             5.0
# 386  can be very corporate since it is already a ve...             4.0
# 204  boring job content and cannot access to the co...             3.0
# 280               hard to promotelow efficiencyand etc             4.0
# 480                           not any cons for tencent             5.0
# 4                        need to be more international             5.0
# 32                               push had to work hard             3.0

# %%
google_df.sample(30)
# Out:
#                      employee_title      location employee_status  \
# 53                Assistant Manager           NaN    17 Jan 2022
# 161               Software Engineer           NaN    26 May 2021
# 184          Senior Account Manager     Singapore    28 Apr 2021
# 167                       Anonymous           NaN    24 May 2021
# 358                       Anonymous           NaN     4 Aug 2019
# 229               Software Engineer     Singapore     2 Apr 2021
# 126            Marketing Specialist     Singapore     4 Aug 2021
# 100                       Anonymous           NaN    12 Oct 2021
# 93                        Anonymous           NaN    25 Oct 2021
# 241              Software Developer     Singapore    29 Jan 2021
# 448                             NaN           NaN    20 Aug 2014
# 280                      Consultant     Singapore    11 Nov 2020
# 226                   Head of Sales     Singapore    27 Feb 2021
# 182                      Consultant     Singapore    17 May 2021
# 107                       Anonymous           NaN   24 Sept 2021
# 97                         Director     Singapore    16 Oct 2021
# 85           Senior Product Manager           NaN    10 Nov 2021
# 15                   Administrative           NaN    12 Apr 2022
# 75                        Anonymous           NaN    22 Dec 2021
# 277                       Anonymous     Singapore    28 Nov 2020
# 488                      Consultant           NaN    20 May 2022
# 479               Marketing Manager           NaN    19 May 2022
# 210              Talent Acquisition     Singapore     4 Apr 2021
# 175                       Recruiter     Singapore    16 May 2021
# 275        Senior Software Engineer           NaN     3 Dec 2020
# 72           Shipping and Receiving     Singapore    15 Dec 2021
# 492                       Anonymous           NaN    18 May 2022
# 52                  Account Manager           NaN    20 Jan 2022
# 80    Vice President Cyber Security  New York, NY     5 Dec 2021
# 114     Senior Solutions Consultant           NaN    30 Aug 2021
#
#                                           review_title  \
# 53                                                good
# 161                                           engineer
# 184  great place to work with a lot of opportunitie...
# 167                                      great company
# 358                    business development consultant
# 229                                     check one time
# 126                                              great
# 100                                it s a good company
# 93                                great culture people
# 241          working at google is an unique oppotunity
# 448                                            awesome
# 280                                               good
# 226                                 best place to work
# 182                                     great compaany
# 107                                               good
# 97          senior level management position in google
# 85                               good work environment
# 15                                                good
# 75   amazing benefits but unhealthy career growth o...
# 277                                        pretty good
# 488                                       good company
# 479                                               good
# 210                          so so company to work for
# 175                                      great company
# 275                                               cool
# 72                                                good
# 492                                      great company
# 52                                               noice
# 80                       nothing significant to report
# 114                            excellent place to work
#
#                                                   pros  \
# 53                 very good leadership and management
# 161                 benefits wlb diversity and culture
# 184  huge opportunity to growgreat culturecompany t...
# 167     great place to work with awesome opportunities
# 358                                                nan
# 229       salary is very good and the only good reason
# 126  great work culture and a high performing team ...
# 100                  very good company in every aspect
# 93   amazing helpful people work life balance us great
# 241          working at google is a unique opportunity
# 448      good work life balance plenty of room to grow
# 280                                                nan
# 226  great experience working with smart motivated ...
# 182                                                nan
# 107        dynamic with strategic management proactive
# 97   fantastic company really care about dei and ma...
# 85        good work environment with decent leadership
# 15                             good company to work at
# 75   benefits they call them the golden handcuffs f...
# 277  good environment friendly colleagues doing ver...
# 488                                                nan
# 479                  benefits salary are the best part
# 210                great benefit and office ammenities
# 175  excellent good culture and environment great p...
# 275              good pay good culture good colleagues
# 72                               learned a lot at here
# 492            1 great culture2 high salary3 free food
# 52     it s very specialise and sometimes abit mundane
# 80                        salary is higher than others
# 114                                                nan
#
#                                                   cons  rating_overall
# 53                  not enough money and too political             5.0
# 161                            tech scope new products             5.0
# 184       high performance expectedgrowth is a default             5.0
# 167                               no cons what so ever             5.0
# 358  ltant4 aug 2019 anonymous employee recommendce...             4.0
# 229  long working hours like very longadvice to man...             1.0
# 126  cross functional management is a must otherwis...             5.0
# 100                 no particular cons to my knowledge             5.0
# 93    growth is slow and decision making is not urgent             5.0
# 241                   it is really stressful sometimes             5.0
# 448  salary not too attractive that said benefits a...             4.0
# 280  ltant in singaporerecommendceo approvalbusines...             3.0
# 226  google is getting bigger so decision making pr...             5.0
# 182  ltant in singaporerecommendceo approvalbusines...             4.0
# 107                     promotions are hard to come by             5.0
# 97     highly competitive promotion is hard to come by             5.0
# 85                slightly slow on the innovation side             5.0
# 15                      none google is a great company             5.0
# 75   toxic political atmosphere that perpetuated a ...             4.0
# 277  bad working hoursmanagement need to be more tr...             5.0
# 488  ltant recommendceo approvalbusiness outlookpro...             5.0
# 479                      work life balance can be awry             5.0
# 210  not as glamorous as what people expect out of ...             4.0
# 175                  none all good positive experience             5.0
# 275               bad management bad work life balance             5.0
# 72                           nothing for cons all good             5.0
# 492  1 you are small contributor who is working on ...             5.0
# 52      very stagnant and sometimes nothing much to do             5.0
# 80                               a lot of junior staff             3.0
# 114  ltant recommendceo approvalbusiness outlookpro...             5.0

# %% [markdown]
# ### Checking for nulls and datatype

# %%
tencent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   employee_title   500 non-null    object
#  1   location         306 non-null    object
#  2   employee_status  500 non-null    object
#  3   review_title     500 non-null    object
#  4   pros             500 non-null    object
#  5   cons             500 non-null    object
#  6   rating_overall   500 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 27.5+ KB

# %%
google_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   employee_title   485 non-null    object
#  1   location         280 non-null    object
#  2   employee_status  500 non-null    object
#  3   review_title     500 non-null    object
#  4   pros             500 non-null    object
#  5   cons             500 non-null    object
#  6   rating_overall   500 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 27.5+ KB

# %%
# changing datatype of column: employee_status
tencent_df['employee_status'] = tencent_df['employee_status'].astype('datetime64[ns]')
google_df['employee_status'] = google_df['employee_status'].astype('datetime64[ns]')

# %%
# check for nulls (tencent)
tencent_df.isnull().sum()
# Out:
# employee_title       0
# location           194
# employee_status      0
# review_title         0
# pros                 0
# cons                 0
# rating_overall       0
# dtype: int64

# %%
# check for nulls (google)
google_df.isnull().sum()
# Out:
# employee_title      15
# location           220
# employee_status      0
# review_title         0
# pros                 0
# cons                 0
# rating_overall       0
# dtype: int64

# %%
# exploring the nulls in google employee title

google_df[google_df['employee_title'].isnull()]
# Out:
#     employee_title      location employee_status  \
# 379            NaN           NaN      2018-10-26
# 408            NaN           NaN      2017-04-10
# 410            NaN           NaN      2017-02-23
# 418            NaN           NaN      2016-10-01
# 422            NaN           NaN      2016-05-08
# 425            NaN  New York, NY      2016-02-14
# 426            NaN           NaN      2016-01-28
# 427            NaN           NaN      2016-01-21
# 434            NaN           NaN      2015-08-14
# 445            NaN           NaN      2014-10-12
# 446            NaN           NaN      2014-10-10
# 448            NaN           NaN      2014-08-20
# 451            NaN           NaN      2014-01-07
# 453            NaN           NaN      2013-10-03
# 458            NaN           NaN      2013-03-13
#
#                                           review_title  \
# 379               very good working environment google
# 408                           my internship experience
# 410                                            analyst
# 418      pros and cons just like any other big company
# 422                             selected for gsoc 2016
# 425                                  great environment
# 426                      online advertising specialist
# 427                                   business manager
# 434         excellent company with limitless potential
# 445                              amazing place to work
# 446  gd perks and great colleagues fun loving and h...
# 448                                            awesome
# 451           great company excellent work environment
# 453              all that glitters is not gold youtube
# 458                            industry analyst intern
#
#                                                   pros  \
# 379                            fun people to work with
# 408  diversity dynamic and helpful teams great work...
# 410                             great place to work at
# 418                                                and
# 422  adds value to your skillset and experience you...
# 425  a place where people come together and produce...
# 426  awesome people great benefits and loads of opp...
# 427         smart colleagues great transparent culture
# 434  awesome food awesome people great benefits and...
# 445                  smart folks and great stuff to do
# 446                    good perks and great colleagues
# 448      good work life balance plenty of room to grow
# 451  free food excellent office location smart moti...
# 453  all the usual i lifestyle ii perks iii flexibi...
# 458            best place to co work and friendly mood
#
#                                                   cons  rating_overall
# 379                     work can be stressful at times             5.0
# 408  sometimes you have short time to socialise wit...             5.0
# 410  nothing that i can think ofadvice to managemen...             5.0
# 418  just like any other big company1 oct 2016 reco...             3.0
# 422  should send at least two t shirts and more goo...             5.0
# 425  needs more people to execute at timesadvice to...             4.0
# 426  it is not the best place to get promoted fasta...             5.0
# 427  extremely competitive harder to advance given ...             5.0
# 434  everything revolves around mountain view hard ...             5.0
# 445         long hours pay is okay and could be higher             5.0
# 446  night calls all the timeadvice to managementch...             4.0
# 448  salary not too attractive that said benefits a...             4.0
# 451  long days working for global company means mul...             4.0
# 453  i work at youtube it is run like an army camp ...             1.0
# 458                       it does not have any defects             5.0

# %%
'''from the above, we can see that some of the null values of employee title can be found in the review title. So we will fill
the employee titles of these'''

# index no (408, 410, 426, 427, 458) impute with position found in review title

google_df.iloc[408, google_df.columns.get_loc('employee_title')] = 'Intern'
google_df.iloc[410, google_df.columns.get_loc('employee_title')] = 'Analyst'
google_df.iloc[426, google_df.columns.get_loc('employee_title')] = 'Online Advertising Specialist'
google_df.iloc[427, google_df.columns.get_loc('employee_title')] = 'Business Manager'
google_df.iloc[458, google_df.columns.get_loc('employee_title')] = 'Industry Analyst Intern'

# %%
# after imputing the title
google_df[google_df['employee_title'].isnull()]
# Out:
#     employee_title      location employee_status  \
# 379            NaN           NaN      2018-10-26
# 418            NaN           NaN      2016-10-01
# 422            NaN           NaN      2016-05-08
# 425            NaN  New York, NY      2016-02-14
# 434            NaN           NaN      2015-08-14
# 445            NaN           NaN      2014-10-12
# 446            NaN           NaN      2014-10-10
# 448            NaN           NaN      2014-08-20
# 451            NaN           NaN      2014-01-07
# 453            NaN           NaN      2013-10-03
#
#                                           review_title  \
# 379               very good working environment google
# 418      pros and cons just like any other big company
# 422                             selected for gsoc 2016
# 425                                  great environment
# 434         excellent company with limitless potential
# 445                              amazing place to work
# 446  gd perks and great colleagues fun loving and h...
# 448                                            awesome
# 451           great company excellent work environment
# 453              all that glitters is not gold youtube
#
#                                                   pros  \
# 379                            fun people to work with
# 418                                                and
# 422  adds value to your skillset and experience you...
# 425  a place where people come together and produce...
# 434  awesome food awesome people great benefits and...
# 445                  smart folks and great stuff to do
# 446                    good perks and great colleagues
# 448      good work life balance plenty of room to grow
# 451  free food excellent office location smart moti...
# 453  all the usual i lifestyle ii perks iii flexibi...
#
#                                                   cons  rating_overall
# 379                     work can be stressful at times             5.0
# 418  just like any other big company1 oct 2016 reco...             3.0
# 422  should send at least two t shirts and more goo...             5.0
# 425  needs more people to execute at timesadvice to...             4.0
# 434  everything revolves around mountain view hard ...             5.0
# 445         long hours pay is okay and could be higher             5.0
# 446  night calls all the timeadvice to managementch...             4.0
# 448  salary not too attractive that said benefits a...             4.0
# 451  long days working for global company means mul...             4.0
# 453  i work at youtube it is run like an army camp ...             1.0

# %%
# as for the other missing employee title, we will instead fillna as "Unknown"
google_df['employee_title'].fillna('Unknown', inplace = True)

# %%
# check if there is any more nulls in employee title
google_df[google_df['employee_title'].isnull()]
# Out:
# Empty DataFrame
# Columns: [employee_title, location, employee_status, review_title, pros, cons, rating_overall]
# Index: []

# %%
# using SimpleImputer with strategy set to most_frequent to impute NaN location to the most common

imputer = SimpleImputer(strategy='most_frequent')
google_df['location'] = imputer.fit_transform(google_df[['location']])
tencent_df['location'] = imputer.fit_transform(tencent_df[['location']])

# %%
# setting up a new column for only year of the review
tencent_df['review_year'] = pandas.DatetimeIndex(tencent_df['employee_status']).year
google_df['review_year'] = pandas.DatetimeIndex(google_df['employee_status']).year

# %%
# removing employee_status (exact date of the review)

tencent_df.drop(columns='employee_status', inplace=True)
google_df.drop(columns='employee_status', inplace=True)

# %%
tencent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   employee_title  500 non-null    object
#  1   location        500 non-null    object
#  2   review_title    500 non-null    object
#  3   pros            500 non-null    object
#  4   cons            500 non-null    object
#  5   rating_overall  500 non-null    float64
#  6   review_year     500 non-null    int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 27.5+ KB

# %%
google_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   employee_title  500 non-null    object
#  1   location        500 non-null    object
#  2   review_title    500 non-null    object
#  3   pros            500 non-null    object
#  4   cons            500 non-null    object
#  5   rating_overall  500 non-null    float64
#  6   review_year     500 non-null    int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 27.5+ KB

# %% [markdown]
# ## Exploratory Data Analysis
# ### Ratings

# %%
# looking ratings of the review

tencent_df['rating_overall'].value_counts(normalize=True).plot(kind='bar')
plt.title('Tecent Ratings')
plt.xlabel('Ratings')
plt.ylabel('Number of Ratings')
# Out:
# Text(0, 0.5, 'Number of Ratings')

# %%
# the distribution of 5.0 + 4.0 ratings
tencent_df['rating_overall'].value_counts(normalize=True)
# Out:
# 5.0    0.468
# 4.0    0.338
# 3.0    0.114
# 1.0    0.042
# 2.0    0.038
# Name: rating_overall, dtype: float64

# %%
google_df['rating_overall'].value_counts(normalize=True).plot(kind='bar')
plt.title('Google Ratings')
plt.xlabel('Ratings')
plt.ylabel('Number of Ratings')
# Out:
# Text(0, 0.5, 'Number of Ratings')

# %%
google_df['rating_overall'].value_counts(normalize=True)
# Out:
# 5.0    0.672
# 4.0    0.208
# 3.0    0.084
# 1.0    0.024
# 2.0    0.012
# Name: rating_overall, dtype: float64

# %% [markdown]
# #### Google had a better rating score at 88% of score between 4 - 5 compared to Tencent at 80.6% of score between 4 - 5

# %% [markdown]
# ###  Location

# %%
# location
sns.catplot(x='location', data=tencent_df, kind='count').limit(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [48], in <cell line: 2>()
#       1 # location
# ----> 2 sns.catplot(x='location', data=tencent_df, kind='count').limit(5)
#
# AttributeError: 'FacetGrid' object has no attribute 'limit'

# %% [markdown]
# ### Year of written review

# %%
year = ['2022', '2021', '2020', '2019', '2018' ,'2017', '2016', '2015', '2014', '2013']
tencent_df['review_year'].value_counts().sort_values(year).plot(kind='bar')
# Out:
# C:\Users\brand\AppData\Local\Temp\ipykernel_12580\2555778776.py:2: FutureWarning: In a future version of pandas all arguments of Series.sort_values will be keyword-only.
#   tencent_df['review_year'].value_counts().sort_values(year).plot(kind='bar')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       1 year = ['2022', '2021', '2020', '2019', '2018' ,'2017', '2016', '2015', '2014', '2013']
# ----> 2 tencent_df['review_year'].value_counts().sort_values(year).plot(kind='bar')
#
# File ~\anaconda3\envs\Glassdoor_scrape\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\Glassdoor_scrape\lib\site-packages\pandas\core\series.py:3502, in Series.sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3500 inplace = validate_bool_kwarg(inplace, "inplace")
#    3501 # Validate the axis parameter
# -> 3502 self._get_axis_number(axis)
#    3504 # GH 5856/5853
#    3505 if inplace and self._is_cached:
#
# File ~\anaconda3\envs\Glassdoor_scrape\lib\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     546 @final
#     547 @classmethod
#     548 def _get_axis_number(cls, axis: Axis) -> int:
#     549     try:
# --> 550         return cls._AXIS_TO_AXIS_NUMBER[axis]
#     551     except KeyError:
#     552         raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# TypeError: unhashable type: 'list'

# %%
google_df['review_year'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### LDA Topic Modeling

# %%
from gensim.corpora.dictionary import Dictionary

# set pros and cons from dataframe into variables
tencent_pros = tencent_df['pros']
tencent_cons = tencent_df['cons']
google_pros = google_df['pros']
google_cons = google_df['cons']

# %% [markdown]
# # remove stopwards, lemmatize, tokenize
