# %% [markdown]
# ## NLP with company reviews on Glassdoor
#
# This capstone project is about helping companies/potential employee identify potential problems within a company. The business focus will be to help potential clients/companies get insights into the problems that existing or past employees faced within the company to reduce the turnover rate, solve potential mental health issues of employees and improve the image of the company. This could also assist the ministry of manpower or ministry with complaints filed by employees on employers for misconduct on determining if such issues has been flagged by other employees of the companies. These are just some of the use case of this project but not just limited to only the use case mentioned above.

# %% [markdown]
# #### Credit to Mathew Chatham for the scraper
# This is to credit Matthew Chatham for the scraper in which he had created and shared on github. The scraper could not work immediately as the codes on glassdoor has changed over the time of 2 -3 years which he created the scraper. Some tweaks was done to update and remove fields that are not required. The link can be found here (https://github.com/MatthewChatham/glassdoor-review-scraper)

# %%
pip list
# Out:
# Package                            Version
# ---------------------------------- --------------------
# absl-py                            1.0.0
# aiohttp                            3.8.1
# aiosignal                          1.2.0
# alabaster                          0.7.12
# anaconda-client                    1.9.0
# anaconda-navigator                 2.1.4
# anaconda-project                   0.10.1
# anyio                              2.2.0
# appdirs                            1.4.4
# applaunchservices                  0.2.1
# appnope                            0.1.2
# appscript                          1.1.2
# argh                               0.26.2
# argon2-cffi                        20.1.0
# arrow                              0.13.1
# asn1crypto                         1.4.0
# astroid                            2.6.6
# astropy                            4.3.1
# astunparse                         1.6.3
# async-generator                    1.10
# async-timeout                      4.0.2
# atomicwrites                       1.4.0
# attrs                              21.2.0
# autopep8                           1.5.7
# Babel                              2.9.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# beautifulsoup4                     4.10.0
# binaryornot                        0.4.4
# bitarray                           2.3.0
# bkcharts                           0.2
# black                              19.10b0
# bleach                             4.0.0
# blis                               0.7.7
# bokeh                              2.4.1
# boto                               2.49.0
# Bottleneck                         1.3.2
# branca                             0.4.2
# brotlipy                           0.7.0
# cached-property                    1.5.2
# cachetools                         4.2.4
# catalogue                          2.0.6
# certifi                            2021.10.8
# cffi                               1.14.6
# chardet                            4.0.0
# charset-normalizer                 2.0.4
# click                              8.0.3
# cloudpickle                        2.0.0
# clyent                             1.2.2
# colorama                           0.4.4
# conda                              4.12.0
# conda-build                        3.21.5
# conda-content-trust                0+unknown
# conda-pack                         0.6.0
# conda-package-handling             1.7.3
# conda-repo-cli                     1.0.4
# conda-token                        0.3.0
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# cookiecutter                       1.7.2
# cryptography                       3.4.8
# cycler                             0.10.0
# cymem                              2.0.6
# Cython                             0.29.24
# cytoolz                            0.11.0
# daal4py                            2021.3.0
# dask                               2021.10.0
# debugpy                            1.4.1
# decorator                          5.1.0
# defusedxml                         0.7.1
# diff-match-patch                   20200713
# distributed                        2021.10.0
# docutils                           0.17.1
# entrypoints                        0.3
# et-xmlfile                         1.1.0
# fastcache                          1.1.0
# filelock                           3.3.1
# flake8                             3.9.2
# Flask                              1.1.2
# flatbuffers                        2.0
# folium                             0.12.1.post1
# fonttools                          4.25.0
# frozenlist                         1.3.0
# fsspec                             2021.8.1
# future                             0.18.2
# gast                               0.5.3
# gevent                             21.8.0
# glob2                              0.7
# gmpy2                              2.0.8
# google-api-core                    2.2.2
# google-auth                        2.3.3
# google-auth-oauthlib               0.4.6
# google-cloud-bigquery              2.24.1
# google-cloud-bigquery-storage      2.11.0
# google-cloud-core                  2.2.2
# google-cloud-storage               2.0.0
# google-crc32c                      1.1.2
# google-pasta                       0.2.0
# google-resumable-media             2.1.0
# googleapis-common-protos           1.54.0
# greenlet                           1.1.1
# grpcio                             1.38.1
# h11                                0.13.0
# h5py                               3.2.1
# HeapDict                           1.0.1
# html5lib                           1.1
# htmlmin                            0.1.12
# idna                               3.2
# imagecodecs                        2021.8.26
# ImageHash                          4.2.1
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 4.8.1
# inflection                         0.5.1
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          6.4.1
# ipython                            7.29.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.6.5
# isort                              5.9.3
# itsdangerous                       2.0.1
# jdcal                              1.4.1
# jedi                               0.18.0
# Jinja2                             2.11.3
# jinja2-time                        0.2.0
# joblib                             1.1.0
# json5                              0.9.6
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.4.0
# jupyter-core                       4.8.1
# jupyter-server                     1.4.1
# jupyterlab                         3.3.2
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  2.10.3
# jupyterlab-widgets                 1.0.0
# keras                              2.8.0
# Keras-Preprocessing                1.1.2
# keyring                            23.1.0
# kiwisolver                         1.3.1
# langcodes                          3.3.0
# lazy-object-proxy                  1.6.0
# libarchive-c                       2.9
# libclang                           13.0.0
# libcst                             0.4.0
# llvmlite                           0.37.0
# locket                             0.2.1
# lxml                               4.6.3
# Markdown                           3.3.6
# MarkupSafe                         2.0.1
# matplotlib                         3.4.3
# matplotlib-inline                  0.1.2
# mccabe                             0.6.1
# missingno                          0.4.2
# mistune                            0.8.4
# mkl-fft                            1.3.1
# mkl-random                         1.2.2
# mkl-service                        2.4.0
# mock                               4.0.3
# more-itertools                     8.10.0
# mpmath                             1.2.1
# msgpack                            1.0.2
# multidict                          6.0.2
# multimethod                        1.7
# multipledispatch                   0.6.0
# munkres                            1.1.4
# murmurhash                         1.0.6
# mypy-extensions                    0.4.3
# navigator-updater                  0.2.1
# nbclassic                          0.2.6
# nbclient                           0.5.3
# nbconvert                          6.1.0
# nbformat                           5.1.3
# nest-asyncio                       1.5.1
# networkx                           2.6.3
# nltk                               3.6.5
# nose                               1.3.7
# notebook                           6.4.5
# numba                              0.54.1
# numexpr                            2.7.3
# numpy                              1.22.4
# numpydoc                           1.1.0
# oauthlib                           3.2.0
# olefile                            0.46
# openpyxl                           3.0.9
# opt-einsum                         3.3.0
# outcome                            1.1.0
# packaging                          21.0
# pandas                             1.3.4
# pandas-profiling                   3.1.0
# pandocfilters                      1.4.3
# parso                              0.8.2
# partd                              1.2.0
# path                               16.0.0
# pathlib2                           2.3.6
# pathspec                           0.7.0
# pathy                              0.6.1
# patsy                              0.5.2
# pep8                               1.7.1
# pexpect                            4.8.0
# phik                               0.12.0
# pickleshare                        0.7.5
# Pillow                             8.4.0
# pip                                22.1.2
# pkginfo                            1.7.1
# pluggy                             0.13.1
# ply                                3.11
# poyo                               0.5.0
# praw                               7.5.0
# prawcore                           2.3.0
# preshed                            3.0.6
# prometheus-client                  0.11.0
# prompt-toolkit                     3.0.20
# proto-plus                         1.19.6
# protobuf                           3.16.0
# psutil                             5.8.0
# ptyprocess                         0.7.0
# py                                 1.10.0
# pyarrow                            4.0.0
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.7
# pycodestyle                        2.7.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.44.1
# pydantic                           1.8.2
# pydocstyle                         6.1.1
# pyerfa                             2.0.0
# pyflakes                           2.3.1
# Pygments                           2.10.0
# PyJWT                              2.1.0
# pylint                             2.9.6
# pyls-spyder                        0.4.0
# pymongo                            3.12.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          21.0.0
# pyparsing                          3.0.4
# pyrsistent                         0.18.0
# PySocks                            1.7.1
# pytest                             6.2.4
# python-dateutil                    2.8.2
# python-lsp-black                   1.0.0
# python-lsp-jsonrpc                 1.0.0
# python-lsp-server                  1.2.4
# python-slugify                     5.0.2
# pytz                               2021.3
# pyu2f                              0.1.5
# PyWavelets                         1.1.1
# PyYAML                             6.0
# pyzmq                              22.2.1
# QDarkStyle                         3.0.2
# qstylizer                          0.1.10
# QtAwesome                          1.0.2
# qtconsole                          5.1.1
# QtPy                               1.10.0
# regex                              2021.8.3
# requests                           2.26.0
# requests-oauthlib                  1.3.1
# rope                               0.19.0
# rsa                                4.8
# Rtree                              0.9.7
# ruamel-yaml-conda                  0.15.100
# scikit-image                       0.18.3
# scikit-learn                       0.24.2
# scikit-learn-intelex               2021.20210714.100439
# scipy                              1.7.1
# seaborn                            0.11.2
# selenium                           4.2.0
# Send2Trash                         1.8.0
# setuptools                         62.3.2
# shellingham                        1.4.0
# simplegeneric                      0.8.1
# singledispatch                     3.7.0
# sip                                4.19.13
# six                                1.16.0
# smart-open                         5.2.1
# sniffio                            1.2.0
# snowballstemmer                    2.1.0
# sortedcollections                  2.1.0
# sortedcontainers                   2.4.0
# soupsieve                          2.2.1
# spacy                              3.3.0
# spacy-legacy                       3.0.9
# spacy-loggers                      1.0.2
# Sphinx                             4.2.0
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             2.0.0
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.5
# sphinxcontrib-websupport           1.2.4
# spyder                             5.1.5
# spyder-kernels                     2.1.3
# SQLAlchemy                         1.4.22
# srsly                              2.4.3
# statsmodels                        0.12.2
# sympy                              1.9
# tables                             3.6.1
# tangled-up-in-unicode              0.1.0
# TBB                                0.2
# tblib                              1.7.0
# tensorboard                        2.8.0
# tensorboard-data-server            0.6.1
# tensorboard-plugin-wit             1.8.1
# tensorflow                         2.8.0
# tensorflow-io-gcs-filesystem       0.24.0
# termcolor                          1.1.0
# terminado                          0.9.4
# testpath                           0.5.0
# text-unidecode                     1.3
# textdistance                       4.2.1
# tf-estimator-nightly               2.8.0.dev2021122109
# thinc                              8.0.16
# thinc-apple-ops                    0.0.7
# threadpoolctl                      2.2.0
# three-merge                        0.1.1
# tifffile                           2021.7.2
# tinycss                            0.4
# toml                               0.10.2
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.62.3
# traitlets                          5.1.0
# trio                               0.20.0
# trio-websocket                     0.9.2
# typed-ast                          1.4.3
# typer                              0.4.1
# typing-extensions                  3.10.0.2
# typing-inspect                     0.7.1
# ujson                              4.0.2
# unicodecsv                         0.14.1
# Unidecode                          1.2.0
# update-checker                     0.18.0
# urllib3                            1.26.7
# visions                            0.7.4
# wasabi                             0.9.1
# watchdog                           2.1.3
# wcwidth                            0.2.5
# webencodings                       0.5.1
# websocket-client                   1.2.3
# Werkzeug                           2.0.2
# wheel                              0.37.1
# whichcraft                         0.6.1
# widgetsnbextension                 3.5.1
# wrapt                              1.12.1
# wsproto                            1.1.0
# wurlitzer                          2.1.1
# xlrd                               2.0.1
# XlsxWriter                         3.0.1
# xlwings                            0.24.9
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.31.0
# yarl                               1.7.2
# zict                               2.0.0
# zipp                               3.6.0
# zope.event                         4.5.0
# zope.interface                     5.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import selenium
import pandas
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
import seaborn as sns
import re
import spacy

# %% [markdown]
# ## Data Extraction
#
# ### Using the scraper to obtain the data and putting it into a DataFrame

# %%
# using the code by Matthew after some updates was done to get the scraper to work

# this is to scrape 500 reviews from glassdoor of Tencent a china internet company
# %run main.py --url "https://www.glassdoor.sg/Reviews/Tencent-Reviews-E38281.htm" --limit 500 -f tencent_reviews.csv

# %%
# this is to scrape 500 reviews from glassdoor of Google a US internet company
# %run main.py --url "https://www.glassdoor.sg/Reviews/Google-Reviews-E9079.htm" --limit 500 -f google_reviews.csv

# %%
# reading the csv file and assign the data to a variable in a dataframe
tencent_df = pandas.read_csv('tencent_reviews.csv')
google_df = pandas.read_csv('google_reviews.csv')

# %%
tencent_df.sample(20)
# Out:
#                      employee_title             location employee_status  \
# 118                        Director            Hong Kong    27 Apr 2022
# 430                 Product Manager  Shenzhen, Guangdong    25 Mar 2021
# 419                    Data Analyst  Shenzhen, Guangdong     7 Apr 2021
# 65        Machine Learning Engineer                  NaN    10 May 2022
# 53         Senior Software Engineer        Palo Alto, CA    19 May 2022
# 343   Software Engineer(Internship)     Chengdu, Sichuan     1 Aug 2021
# 325                       Anonymous                  NaN    28 Aug 2021
# 251                  Robot Engineer  Shenzhen, Guangdong    11 Nov 2021
# 122                       Anonymous                  NaN    20 Mar 2022
# 67                        Anonymous                  NaN    24 Apr 2022
# 229                        Director   Shanghai, Shanghai    13 Dec 2021
# 74        Technical Program Manager                  NaN     5 May 2022
# 278          Senior DevOps Engineer                  NaN     1 Oct 2021
# 206               Android Developer  Shenzhen, Guangdong     5 Feb 2022
# 457              Software Developer                  NaN     4 Mar 2021
# 41                        Anonymous                  NaN     3 Jul 2019
# 90                     Data Analyst                  NaN    22 Apr 2022
# 313       Senior Frontend Developer  Shenzhen, Guangdong   12 Sept 2021
# 51                  Project Manager            Hong Kong     5 May 2022
# 456                         Manager                  NaN     2 Mar 2021
#
#                                       review_title  \
# 118  Good for CV but really underdeveloped company
# 430                good company with great culture
# 419                              Data Science Team
# 65                                          Review
# 53                        Poorly Managed Media Lab
# 343       Software Engineer(Internship) at Tencent
# 325                                Jobdesk Unclear
# 251                     Overtime is a bit too much
# 122                                           Good
# 67                         Nice company to work at
# 229                                           good
# 74                     Famous but not in technical
# 278                                        Reviews
# 206                   Overtime extreamly force PIP
# 457                            Be happy, be strong
# 41                       The best company in China
# 90                  Nice Pay Low Work Life Balance
# 313                                   Good Company
# 51                                           Great
# 456             Great company but not for everyone
#
#                                                   pros  \
# 118  Headquarters with canteen and entertainment; l...
# 430  good for new graduates to grow up, profound re...
# 419                  The work life balance is better\n
# 65    Good work experience\nGood benefits and salary\n
# 53   Not a lot of pros: \nGood work\nFree lunch\nNi...
# 343  1. Good work-life balance.\n2. Greate lunch an...
# 325               - Good work ethic\n- Good facility\n
# 251  Salary is fine in that city if you dont buy an...
# 122                    Good payment and low pressure\n
# 67              friendly people and good environment\n
# 229                    overall good payment in china\n
# 74            Good fame and work conditions, benefit\n
# 278                Good benefits and company culture\n
# 206          high salary in china\nfree food is fine\n
# 457  staff care, technology growth, career opportun...
# 41                Full of the greatest young people.\n
# 90           1. locally comatitive pay\n2. insurance\n
# 313       * Good working environment\n* Good welfare\n
# 51                  Good work and challenge is great\n
# 456       fast growing opportunity and great package\n
#
#                                                   cons  rating_overall
# 118  Top down boss pleasing culture, no clear KPI, ...             1.0
# 430  too many departments in a big company, hard to...             5.0
# 419  Our team seems not very good\nBe the first to ...             5.0
# 65   No significant cons. I am satisfied with curre...             4.0
# 53   No sync among managers and higher executive\nO...             2.0
# 343  1. Low salary, but it is relatively high than ...             4.0
# 325  - Indonesian office function is more like agen...             2.0
# 251  Overtime is a bit too much, and the prices of ...             3.0
# 122  Bad environment in working facility\nBe the fi...             5.0
# 67   long working hours and some times intense work...             5.0
# 229  long hours with complicated communication proc...             4.0
# 74   Management is a mess. Could be better but none...             4.0
# 278  Work/life balance, the company is based in Chi...             5.0
# 206  overtime extremely over 60hours per week\nAgei...             1.0
# 457  over work, not wlb, bad senior management\nBe ...             4.0
# 41   Mid level management is the weakness\nBe the f...             4.0
# 90   1. no work life balance\n2. pay is not enough ...             4.0
# 313  * The technology stack is a bit outdated\nBe t...             4.0
# 51   Location is an issue for sure\nBe the first to...             5.0
# 456  No work life balance and complicated structure...             4.0

# %%
google_df.sample(20)
# Out:
#                     employee_title               location employee_status  \
# 199                        Analyst              Singapore     7 Apr 2021
# 239                      Anonymous                    NaN     3 Feb 2021
# 163            Contract Specialist              Singapore     9 Jun 2021
# 474              Assistant Manager              Bangalore    21 May 2022
# 171                Account Manager  Jurong West New Town,    19 May 2021
# 197                      Anonymous                    NaN    29 Apr 2021
# 293   Google Engineering Practicum              Singapore   25 Sept 2020
# 89              Head Of Operations                    NaN     3 Nov 2021
# 275       Senior Software Engineer                    NaN     3 Dec 2020
# 445                            NaN                    NaN    12 Oct 2014
# 380                      Anonymous                    NaN   19 Sept 2018
# 248                      Anonymous                    NaN    22 Jan 2021
# 211                      Anonymous                    NaN     2 Apr 2021
# 156                Sales Associate              Singapore     8 Jun 2021
# 122                            Tax              Singapore    12 Aug 2021
# 232               Industry Manager              Singapore    30 Mar 2021
# 54                       Anonymous                    NaN    13 Jan 2022
# 200                      Anonymous                    NaN     1 Apr 2021
# 151   Business Development Manager                    NaN    27 Jun 2021
# 441                Account Manager                    NaN     2 Jan 2015
#
#                             review_title  \
# 199                   Good place to work
# 239       Google cares for its employees
# 163                            Great job
# 474  Best Opportunity at Indianmoney.com
# 171                                   AE
# 197          Excellent work life balance
# 293          Good place to start career.
# 89                          Good culture
# 275                                 Cool
# 445                Amazing place to work
# 380                       AccountManager
# 248                            Dream job
# 211                      Getting too big
# 156                   Good place to work
# 122                        Great company
# 232     Politics, politics, and politics
# 54                                  good
# 200                                 Good
# 151                                 Good
# 441                        Best job ever
#
#                                                   pros  \
# 199                    Good benefits and Good people\n
# 239   They are very supportive of WFH and well-being\n
# 163                Great package and benefits always\n
# 474     Working since very long and good environment\n
# 171  Benefits, compensation, smart people, good pro...
# 197    Excellent remuneration, and work life balance\n
# 293      Easy Going and plenty of employee benefits.\n
# 89              Strong employee Benefits and culture\n
# 275            Good pay good culture good colleagues\n
# 445               Smart folks and great stuff to do.\n
# 380              Great Culture & capable team member\n
# 248  Culture , compensation, product , challenge , ...
# 211  Great perks, people are great, and people know...
# 156                      Good place to work, thanks!\n
# 122               Good benefits with great community\n
# 232  - talented colleague\n- good perks\n- good bra...
# 54      1. wlb\n2. great infra\n3. great engineering\n
# 200            Really good compensation and benefits\n
# 151                      Good food, pay and friendly\n
# 441  Literally everything\nThe facilities are incre...
#
#                                                   cons  rating_overall
# 199  No inspirational vision as a team, too competi...             5.0
# 239  It's a high pressure environment\nBe the first...             5.0
# 163  Lack of ethics in Business operations\nAdvice ...             3.0
# 474  More than 6 years at IndianMoney.com\nAdvice t...             5.0
# 171  slow promotion, red tapes, political\nBe the f...             5.0
# 197  A really high performing organization and with...             4.0
# 293  Sometimes lack structure and timing.\nBe the f...             5.0
# 89   Complicated org structure and silos\nBe the fi...             5.0
# 275  Bad management bad work life balance\nBe the f...             5.0
# 445  long hours, pay is okay and could be higher\nB...             5.0
# 380  Promotion is hard to get and there is a lot of...             5.0
# 248  Performance review by semester very ambiguous ...             5.0
# 211  Getting too big, leadership is absent\nBe the ...             3.0
# 156  Too much food! I'm fat now\nBe the first to fi...             5.0
# 122  Segmented responsibilities due to the size\nBe...             5.0
# 232  - politics\n- terrible people manager\n- too m...             1.0
# 54   1. move slow\n2. feel less impact\nBe the firs...             5.0
# 200  Nothing much to talk about\nBe the first to fi...             5.0
# 151  Hurried, fast, no time to do stuff\nBe the fir...             4.0
# 441  Nothing to be honest\nReally nothing at all\nE...             5.0

# %% [markdown]
# ## Data Preprocessing
#
# ### Creating a helper function to clean the text for title, pros and cons

# %%
# helper function to clean the data for pros

def clean_text_pros(text):
    # remove "/n"
    pattern1 = re.compile(r'\n')
    text = pattern1.sub(r'',text)
    # remove irrelevant character such as numbers and punctutation
    pattern2 = re.compile(r'[^a-zA-Z0-9]')
    text = pattern2.sub(r' ',text)
    # remove extra whitespaces
    pattern3 = re.compile(r'^\s*|\s\s*')
    text = pattern3.sub(r' ', text).strip()
    # text to all lower case
    text = text.lower()
    
    return text

# helper function to clean the data for cons

def clean_text_cons(text):
    # remove the text that is not part of the actual comments
    pattern1 = re.compile(r'\nBe\sthe\sfirst.+')
    text = pattern1.sub(r'',text)
    pattern2 = re.compile(r'\d\speople\sfound\sthis.+')
    text = pattern2.sub(r'',text)
    pattern3 = re.compile(r'\d\sperson\sfound.+')
    text = pattern3.sub(r'',text)
    pattern4 = re.compile(r'\nHelpful\nShare\nRepor')
    text = pattern4.sub(r'',text)
    
    # remove "/n"
    pattern5 = re.compile(r'\n')
    text = pattern5.sub(r'',text)
    # remove irrelevant character such as numbers and punctuation
    pattern6 = re.compile(r'[^a-zA-Z0-9]')
    text = pattern6.sub(r' ',text)
    # remove extra whitespaces
    pattern7= re.compile(r'^\s*|\s\s*')
    text = pattern7.sub(r' ', text).strip()
    # text to all lower case
    text = text.lower()
    
    return text

def clean_title(text):
    # remove "/n"
    pattern1 = re.compile(r'\n')
    text = pattern1.sub(r'',text)
    # remove irrelevant character such as numbers and punctutation
    pattern2 = re.compile(r'[^a-zA-Z0-9]')
    text = pattern2.sub(r' ',text)
    # remove extra whitespaces
    pattern3 = re.compile(r'^\s*|\s\s*')
    text = pattern3.sub(r' ', text).strip()
    # text to all lower case
    text = text.lower()
    
    return text

# %%
# running the helper function to clean both google and tencent dataset

tencent_df['pros'] = tencent_df['pros'].map(lambda x: clean_text_pros(str(x)))
tencent_df['cons'] = tencent_df['cons'].map(lambda x: clean_text_cons(x))
tencent_df['review_title'] = tencent_df['review_title'].map(lambda x: clean_title(str(x)))
google_df['pros'] = google_df['pros'].map(lambda x: clean_text_pros(str(x)))
google_df['cons'] = google_df['cons'].map(lambda x: clean_text_cons(x))
google_df['review_title'] = google_df['review_title'].map(lambda x: clean_title(str(x)))

# %%
tencent_df.sample(30)
# Out:
#                      employee_title              location employee_status  \
# 375              Software Developer    Shanghai, Shanghai    25 Jun 2021
# 15         Senior Software Engineer             Singapore    22 Feb 2022
# 440                   Design Leader   Shenzhen, Guangdong    11 Mar 2021
# 74        Technical Program Manager                   NaN     5 May 2022
# 356               Software Engineer   Shenzhen, Guangdong    22 Jun 2021
# 382   Software Test Engineer Intern  Guangzhou, Guangdong    27 May 2021
# 423               Software Engineer     San Francisco, CA     1 Apr 2021
# 200                       3D Artist          Montreal, WI     5 Jan 2022
# 320                 Product Manager   Shenzhen, Guangdong    18 Aug 2021
# 406                       Anonymous      Beijing, Beijing    18 Apr 2021
# 114                 Human Resources                   NaN    24 Mar 2022
# 104               Global Operations   Shenzhen, Guangdong    31 Mar 2022
# 395                  Office Manager   Shenzhen, Guangdong    30 Apr 2021
# 324        Senior Software Engineer   Shenzhen, Guangdong    29 Aug 2021
# 482                Business Analyst                   NaN    20 Jan 2021
# 332      Talent Development Manager                   NaN     5 Aug 2021
# 109                       Anonymous                   NaN    13 Apr 2022
# 319                 Product Manager      Beijing, Beijing    19 Aug 2021
# 90                     Data Analyst                   NaN    22 Apr 2022
# 81               Front End Engineer                   NaN    17 Apr 2022
# 343   Software Engineer(Internship)      Chengdu, Sichuan     1 Aug 2021
# 178                       Anonymous                   NaN    12 Feb 2022
# 87             Full Stack Developer                   NaN    27 Apr 2022
# 262               Software Engineer   Shenzhen, Guangdong    18 Oct 2021
# 359                   Game Designer      Beijing, Beijing    15 Jun 2021
# 281                    Game Liaison               Tbilisi    13 Oct 2021
# 24                        Anonymous             Singapore    6 Sept 2021
# 436                 Product Manager   Shenzhen, Guangdong    16 Mar 2021
# 298                       Anonymous                   NaN     2 Oct 2021
# 409                Business Analyst          New York, NY    13 Apr 2021
#
#                                           review_title  \
# 375                                                  1
# 15                          yet another company review
# 440                                                121
# 74                         famous but not in technical
# 356                                               good
# 382                                      good location
# 423                                  very good company
# 200                                               high
# 320                                       good company
# 406                             best employer in china
# 114                                                100
# 104  chinese tech giant on the way to become a glob...
# 395                              best company i ve met
# 324                                               good
# 482                        overall it s a good company
# 332                                company environment
# 109                                            neutral
# 319                                    product manager
# 90                      nice pay low work life balance
# 81                                                nice
# 343            software engineer internship at tencent
# 178                          tencent software engineer
# 87         working in tencent is a valuable experience
# 262                                              great
# 359                                                nan
# 281
# 24                                          contractor
# 436                                   good enviornment
# 298                                  working mechanism
# 409                                            tencent
#
#                                                   pros  \
# 375                    has good benefits for employees
# 15   1 good compensation2 a lot of internal resourc...
# 440             good company good culture good partner
# 74               good fame and work conditions benefit
# 356                        good enough less spare time
# 382                      big name good place great pay
# 423                  work life balance is not so great
# 200                          really good place to work
# 320        nice platform to develop for fresh graduate
# 406  great facility and benefits we have a gym bask...
# 114                 great culture very people centered
# 104  startup mindset flat teams nice mix of china i...
# 395  competitive compensations in china and everyon...
# 324                        big name care about workers
# 482      competitive salaries cozy working environment
# 332           nicely working environment for employees
# 109                               salary is a bit high
# 319      good salarygood astomspheregood talentgood tb
# 90                 1 locally comatitive pay2 insurance
# 81         big platform better welfare lead technology
# 343  1 good work life balance 2 greate lunch and di...
# 178                    good welfare and good treatment
# 87   i can get in touch with many technical giants ...
# 262                      great place to work and learn
# 359                           good food a lot of games
# 281   got some in game moneys and work was pretty easy
# 24   so so job chinese culture young colleagues rap...
# 436  compared with other chinese giant companies th...
# 298                           good way to china market
# 409                   talented people and good culture
#
#                                                   cons  rating_overall
# 375            not very open culture overally speaking             1.0
# 15   1 ancient infra huge tech debts messy workflow...             3.0
# 440                 good good good good good good good             5.0
# 74   management is a mess could be better but none ...             4.0
# 356                          ok soso paid not too much             5.0
# 382            working overtime is a kind of a problem             4.0
# 423                     growth opportunity is very big             5.0
# 200  long hours and to much otadvice to managementl...             5.0
# 320  you should have to face the changes and challe...             5.0
# 406  frequent organizational changesslow decision m...             5.0
# 114                   not a big presence in canada yet             5.0
# 104  most of the culture is quite china centric but...             5.0
# 395  always has a long process and really stressful...             5.0
# 324         work tired too much work need to be oncall             4.0
# 482                    too much politics no creativity             4.0
# 332  too much communication as so many stakeholders...             5.0
# 109  no freedom in research topic no vision in long...             2.0
# 319                no wlbtoo pushcolleague never sleep             5.0
# 90   1 no work life balance2 pay is not enough to s...             4.0
# 81                  busy lack of promotion lack of wlb             5.0
# 343  1 low salary but it is relatively high than co...             4.0
# 178                     good environment and good boss             4.0
# 87   the meeting usually needs to confirm some smal...             4.0
# 262  work time is long and everyone takes it for gr...             5.0
# 359      long working hours female and male unbalanced             5.0
# 281  not really had a cons but it wasn a job that g...             4.0
# 24   not recommended for contractors bad for career...             3.0
# 436  the compensation is not the top compared with ...             5.0
# 298  too many unnecessary working flow and approval...             3.0
# 409       bureaucracy and the assignment often changes             5.0

# %%
google_df.sample(30)
# Out:
#                              employee_title             location  \
# 328                               Anonymous                  NaN
# 107                               Anonymous                  NaN
# 326                        Sales Operations                  NaN
# 106                         Project Manager            Singapore
# 190               Strategic Partner Manager  Bukit Merah Estate,
# 1                  Senior Financial Analyst            Singapore
# 47                               HR Manager            Singapore
# 336                      Marketing Director      Bedok New Town,
# 197                               Anonymous                  NaN
# 275                Senior Software Engineer                  NaN
# 370                               Anonymous            Singapore
# 425                                     NaN         New York, NY
# 34                             Data Analyst                  NaN
# 19                             Temp to Perm            Singapore
# 31                          Sales Executive                  NaN
# 177                               Executive            Singapore
# 2                                Programmer                  NaN
# 257                               Anonymous                  NaN
# 74                         Industry Manager            Singapore
# 12                        Global Consultant                  NaN
# 332                               Anonymous                  NaN
# 401                               Recruiter                  NaN
# 311                              Technician      Bedok New Town,
# 399   Senior Technical Solutions Consultant            Singapore
# 320                    Sales Representative            Singapore
# 198                              Internship            Singapore
# 123                               Anonymous            Singapore
# 119                             Consultant             Singapore
# 384                               Anonymous                  NaN
# 226                           Head of Sales            Singapore
#
#     employee_status                                       review_title  \
# 328     9 Apr 2020                                  good place to work
# 107   24 Sept 2021                                                good
# 326    11 May 2020                                 google cloud google
# 106     9 Oct 2021                                  focused on results
# 190    23 Apr 2021                           best company in the world
# 1      15 May 2022                                       great company
# 47     10 Feb 2022
# 336     6 Feb 2020                                           marketing
# 197    29 Apr 2021                         excellent work life balance
# 275     3 Dec 2020                                                cool
# 370    26 Mar 2019                                       a happy place
# 425    14 Feb 2016                                   great environment
# 34     28 Feb 2022                                        good culture
# 19      9 Apr 2022                                                good
# 31     13 Mar 2022                                                good
# 177    11 May 2021                                                 nan
# 2      11 May 2022                                                good
# 257    27 Jan 2021                                        good company
# 74      8 Dec 2021                                                   a
# 12      5 May 2022                                 great place to work
# 332     8 Mar 2020                                      great employer
# 401    17 Oct 2017   used to be great now just a normal corporate n...
# 311     8 Jul 2020                                          tine water
# 399   13 Sept 2017                            best company to work for
# 320    28 May 2020                                       great company
# 198    14 Apr 2021                                software engineering
# 123    12 Aug 2021                                   admin role review
# 119    16 Aug 2021                              secure but slow moving
# 384    30 Jul 2018                                    golden handcuffs
# 226    27 Feb 2021                                  best place to work
#
#                                                   pros  \
# 328                 good benefits and flexible culture
# 107        dynamic with strategic management proactive
# 326  google umbrella brand perks the singapore offi...
# 106    flexible company that caters for remote working
# 190  very supportive but high paced innovative envi...
# 1    culture promotes diversity and inclusion respe...
# 47                    good place to work good benefits
# 336  surrounded by highly intellectual and motivate...
# 197       excellent remuneration and work life balance
# 275              good pay good culture good colleagues
# 370            brilliant people flexible work schedule
# 425  a place where people come together and produce...
# 34                  work life balance and good conduct
# 19                            good good good good good
# 31                 good environment and friendly staff
# 177                             overall it is still ok
# 2                             very good good good good
# 257                    perks and generally good people
# 74                         great place to work overall
# 12                                                 nan
# 332  amazing perks very people oriented supportive ...
# 401  pay standard is still good good benefits and p...
# 311      technology lifestyle brand salary devastating
# 399                                                nan
# 320          perks and people benefits great insurance
# 198           good work environment helpful colleagues
# 123  a good and progressive company to work for man...
# 119                                                nan
# 384  amazing company to start off in insane perks i...
# 226  great experience working with smart motivated ...
#
#                                                   cons  rating_overall
# 328     hard to navigate teams are constantly changing             4.0
# 107                     promotions are hard to come by             5.0
# 326  this only pertains to google cloud and not the...             1.0
# 106  compensation is fair but could work on hiring ...             4.0
# 190  people are just too nice some time advice to m...             5.0
# 1                            not really any major cons             5.0
# 47           chaotic work environment lack of planning             4.0
# 336                    top heavy and getting political             5.0
# 197  a really high performing organization and with...             4.0
# 275               bad management bad work life balance             5.0
# 370        demanding environment and often competitive             5.0
# 425  needs more people to execute at timesadvice to...             4.0
# 34                honestly no cons happy working there             5.0
# 19                            none that i can think of             5.0
# 31                         as of now cant think of one             5.0
# 177         it is a good companyadvice to managementna             5.0
# 2                           salary not high enough tho             5.0
# 257              big company can lead to some politics             4.0
# 74                 hard for career progression overall             5.0
# 12   ltant recommendceo approvalbusiness outlookpro...             4.0
# 332  is becoming more corporate in processes etc gi...             5.0
# 401  when i joined google 7 years ago i used to be ...             1.0
# 311                           tech life broad pay hood             3.0
# 399  ltant in singaporerecommendceo approvalbusines...             5.0
# 320             rigid and slow because its too big now             5.0
# 198                    no downsides from my experience             5.0
# 123  sometimes you can feel a little lost amidst bu...             5.0
# 119  ltant strategy operations in singaporerecommen...             5.0
# 384  can be afraid to leave get syphoned off into o...             4.0
# 226  google is getting bigger so decision making pr...             5.0

# %% [markdown]
# ### Checking for nulls and datatype

# %%
tencent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   employee_title   500 non-null    object
#  1   location         306 non-null    object
#  2   employee_status  500 non-null    object
#  3   review_title     500 non-null    object
#  4   pros             500 non-null    object
#  5   cons             500 non-null    object
#  6   rating_overall   500 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 27.5+ KB

# %%
google_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   employee_title   485 non-null    object
#  1   location         280 non-null    object
#  2   employee_status  500 non-null    object
#  3   review_title     500 non-null    object
#  4   pros             500 non-null    object
#  5   cons             500 non-null    object
#  6   rating_overall   500 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 27.5+ KB

# %%
# changing datatype of column: employee_status
tencent_df['employee_status'] = tencent_df['employee_status'].astype('datetime64[ns]')
google_df['employee_status'] = google_df['employee_status'].astype('datetime64[ns]')

# %%
# check for nulls (tencent)
tencent_df.isnull().sum()
# Out:
# employee_title       0
# location           194
# employee_status      0
# review_title         0
# pros                 0
# cons                 0
# rating_overall       0
# dtype: int64

# %%
# check for nulls (google)
google_df.isnull().sum()
# Out:
# employee_title      15
# location           220
# employee_status      0
# review_title         0
# pros                 0
# cons                 0
# rating_overall       0
# dtype: int64

# %%
# exploring the nulls in google employee title

google_df[google_df['employee_title'].isnull()]
# Out:
#     employee_title      location employee_status  \
# 379            NaN           NaN      2018-10-26
# 408            NaN           NaN      2017-04-10
# 410            NaN           NaN      2017-02-23
# 418            NaN           NaN      2016-10-01
# 422            NaN           NaN      2016-05-08
# 425            NaN  New York, NY      2016-02-14
# 426            NaN           NaN      2016-01-28
# 427            NaN           NaN      2016-01-21
# 434            NaN           NaN      2015-08-14
# 445            NaN           NaN      2014-10-12
# 446            NaN           NaN      2014-10-10
# 448            NaN           NaN      2014-08-20
# 451            NaN           NaN      2014-01-07
# 453            NaN           NaN      2013-10-03
# 458            NaN           NaN      2013-03-13
#
#                                           review_title  \
# 379               very good working environment google
# 408                           my internship experience
# 410                                            analyst
# 418      pros and cons just like any other big company
# 422                             selected for gsoc 2016
# 425                                  great environment
# 426                      online advertising specialist
# 427                                   business manager
# 434         excellent company with limitless potential
# 445                              amazing place to work
# 446  gd perks and great colleagues fun loving and h...
# 448                                            awesome
# 451           great company excellent work environment
# 453              all that glitters is not gold youtube
# 458                            industry analyst intern
#
#                                                   pros  \
# 379                            fun people to work with
# 408  diversity dynamic and helpful teams great work...
# 410                             great place to work at
# 418                                                and
# 422  adds value to your skillset and experience you...
# 425  a place where people come together and produce...
# 426  awesome people great benefits and loads of opp...
# 427         smart colleagues great transparent culture
# 434  awesome food awesome people great benefits and...
# 445                  smart folks and great stuff to do
# 446                    good perks and great colleagues
# 448      good work life balance plenty of room to grow
# 451  free food excellent office location smart moti...
# 453  all the usual i lifestyle ii perks iii flexibi...
# 458            best place to co work and friendly mood
#
#                                                   cons  rating_overall
# 379                     work can be stressful at times             5.0
# 408  sometimes you have short time to socialise wit...             5.0
# 410  nothing that i can think ofadvice to managemen...             5.0
# 418  just like any other big company1 oct 2016 reco...             3.0
# 422  should send at least two t shirts and more goo...             5.0
# 425  needs more people to execute at timesadvice to...             4.0
# 426  it is not the best place to get promoted fasta...             5.0
# 427  extremely competitive harder to advance given ...             5.0
# 434  everything revolves around mountain view hard ...             5.0
# 445         long hours pay is okay and could be higher             5.0
# 446  night calls all the timeadvice to managementch...             4.0
# 448  salary not too attractive that said benefits a...             4.0
# 451  long days working for global company means mul...             4.0
# 453  i work at youtube it is run like an army camp ...             1.0
# 458                       it does not have any defects             5.0

# %%
'''from the above, we can see that some of the null values of employee title can be found in the review title. So we will fill
the employee titles of these'''

# index no (408, 410, 426, 427, 458) impute with position found in review title

google_df.iloc[408, google_df.columns.get_loc('employee_title')] = 'Intern'
google_df.iloc[410, google_df.columns.get_loc('employee_title')] = 'Analyst'
google_df.iloc[426, google_df.columns.get_loc('employee_title')] = 'Online Advertising Specialist'
google_df.iloc[427, google_df.columns.get_loc('employee_title')] = 'Business Manager'
google_df.iloc[458, google_df.columns.get_loc('employee_title')] = 'Industry Analyst Intern'

# %%
# after imputing the title
google_df[google_df['employee_title'].isnull()]
# Out:
#     employee_title      location employee_status  \
# 379            NaN           NaN      2018-10-26
# 418            NaN           NaN      2016-10-01
# 422            NaN           NaN      2016-05-08
# 425            NaN  New York, NY      2016-02-14
# 434            NaN           NaN      2015-08-14
# 445            NaN           NaN      2014-10-12
# 446            NaN           NaN      2014-10-10
# 448            NaN           NaN      2014-08-20
# 451            NaN           NaN      2014-01-07
# 453            NaN           NaN      2013-10-03
#
#                                           review_title  \
# 379               very good working environment google
# 418      pros and cons just like any other big company
# 422                             selected for gsoc 2016
# 425                                  great environment
# 434         excellent company with limitless potential
# 445                              amazing place to work
# 446  gd perks and great colleagues fun loving and h...
# 448                                            awesome
# 451           great company excellent work environment
# 453              all that glitters is not gold youtube
#
#                                                   pros  \
# 379                            fun people to work with
# 418                                                and
# 422  adds value to your skillset and experience you...
# 425  a place where people come together and produce...
# 434  awesome food awesome people great benefits and...
# 445                  smart folks and great stuff to do
# 446                    good perks and great colleagues
# 448      good work life balance plenty of room to grow
# 451  free food excellent office location smart moti...
# 453  all the usual i lifestyle ii perks iii flexibi...
#
#                                                   cons  rating_overall
# 379                     work can be stressful at times             5.0
# 418  just like any other big company1 oct 2016 reco...             3.0
# 422  should send at least two t shirts and more goo...             5.0
# 425  needs more people to execute at timesadvice to...             4.0
# 434  everything revolves around mountain view hard ...             5.0
# 445         long hours pay is okay and could be higher             5.0
# 446  night calls all the timeadvice to managementch...             4.0
# 448  salary not too attractive that said benefits a...             4.0
# 451  long days working for global company means mul...             4.0
# 453  i work at youtube it is run like an army camp ...             1.0

# %%
# as for the other missing employee title, we will instead fillna as "Unknown"
google_df['employee_title'].fillna('Unknown', inplace = True)

# %%
# check if there is any more nulls in employee title
google_df[google_df['employee_title'].isnull()]
# Out:
# Empty DataFrame
# Columns: [employee_title, location, employee_status, review_title, pros, cons, rating_overall]
# Index: []

# %%
# using SimpleImputer with strategy set to most_frequent to impute NaN location to the most common

imputer = SimpleImputer(strategy='most_frequent')
google_df['location'] = imputer.fit_transform(google_df[['location']])
tencent_df['location'] = imputer.fit_transform(tencent_df[['location']])

# %%
# setting up a new column for only year of the review
tencent_df['review_year'] = pandas.DatetimeIndex(tencent_df['employee_status']).year
google_df['review_year'] = pandas.DatetimeIndex(google_df['employee_status']).year

# %%
# removing employee_status (exact date of the review)

tencent_df.drop(columns='employee_status', inplace=True)
google_df.drop(columns='employee_status', inplace=True)

# %%
tencent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   employee_title  500 non-null    object
#  1   location        500 non-null    object
#  2   review_title    500 non-null    object
#  3   pros            500 non-null    object
#  4   cons            500 non-null    object
#  5   rating_overall  500 non-null    float64
#  6   review_year     500 non-null    int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 27.5+ KB

# %%
google_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   employee_title  500 non-null    object
#  1   location        500 non-null    object
#  2   review_title    500 non-null    object
#  3   pros            500 non-null    object
#  4   cons            500 non-null    object
#  5   rating_overall  500 non-null    float64
#  6   review_year     500 non-null    int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 27.5+ KB

# %% [markdown]
# ## Exploratory Data Analysis
# ### Ratings

# %%
# looking ratings of the review

tencent_df['rating_overall'].value_counts(normalize=True).plot(kind='bar')
plt.title('Tecent Ratings')
plt.xlabel('Ratings')
plt.ylabel('Number of Ratings')
# Out:
# Text(0, 0.5, 'Number of Ratings')

# %%
# the distribution of 5.0 + 4.0 ratings
tencent_df['rating_overall'].value_counts(normalize=True)
# Out:
# 5.0    0.468
# 4.0    0.338
# 3.0    0.114
# 1.0    0.042
# 2.0    0.038
# Name: rating_overall, dtype: float64

# %%
google_df['rating_overall'].value_counts(normalize=True).plot(kind='bar')
plt.title('Google Ratings')
plt.xlabel('Ratings')
plt.ylabel('Number of Ratings')
# Out:
# Text(0, 0.5, 'Number of Ratings')

# %%
google_df['rating_overall'].value_counts(normalize=True)
# Out:
# 5.0    0.672
# 4.0    0.208
# 3.0    0.084
# 1.0    0.024
# 2.0    0.012
# Name: rating_overall, dtype: float64

# %% [markdown]
# #### Google had a better rating score at 88% of score between 4 - 5 compared to Tencent at 80.6% of score between 4 - 5

# %% [markdown]
# ###  Location

# %%
# location
sns.catplot(x='location', data=tencent_df, kind='count').limit(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [48], in <cell line: 2>()
#       1 # location
# ----> 2 sns.catplot(x='location', data=tencent_df, kind='count').limit(5)
#
# AttributeError: 'FacetGrid' object has no attribute 'limit'

# %% [markdown]
# ### Year of written review

# %%
# written reviews over the years (tencent)
tencent_df['review_year'].value_counts().sort_index(level='review_year', ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# written reviews over the years (google)
google_df['review_year'].value_counts().sort_index(level='review_year', ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### LDA Topic Modeling

# %%
from gensim.corpora.dictionary import Dictionary

# set pros and cons from dataframe into variables
tencent_pros = tencent_df['pros']
tencent_cons = tencent_df['cons']
google_pros = google_df['pros']
google_cons = google_df['cons']

# %% [markdown]
# # remove stopwards, lemmatize, tokenize
