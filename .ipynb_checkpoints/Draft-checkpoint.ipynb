# %% [markdown]
# ### Things to resolve
#
# text cleaning

# %%
import pandas as pd
import re
import seaborn

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas>=0.23 in c:\users\brand\anaconda3\envs\glassdoor_scrape\lib\site-packages (from seaborn) (1.4.2)
# Requirement already satisfied: numpy>=1.15 in c:\users\brand\anaconda3\envs\glassdoor_scrape\lib\site-packages (from seaborn) (1.22.3)
# Requirement already satisfied: matplotlib>=2.2 in c:\users\brand\anaconda3\envs\glassdoor_scrape\lib\site-packages (from seaborn) (3.5.2)
# Collecting scipy>=1.0
#   Downloading scipy-1.8.1-cp39-cp39-win_amd64.whl (36.9 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\brand\anaconda3\envs\glassdoor_scrape\lib\site-packages (from matplotlib>=2.2->seaborn) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\brand\anaconda3\envs\glassdoor_scrape\lib\site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\brand\anaconda3\envs\glassdoor_scrape\lib\site-packages (from matplotlib>=2.2->seaborn) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\brand\anaconda3\envs\glassdoor_scrape\lib\site-packages (from matplotlib>=2.2->seaborn) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\brand\anaconda3\envs\glassdoor_scrape\lib\site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\brand\anaconda3\envs\glassdoor_scrape\lib\site-packages (from matplotlib>=2.2->seaborn) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\brand\anaconda3\envs\glassdoor_scrape\lib\site-packages (from matplotlib>=2.2->seaborn) (9.1.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\brand\anaconda3\envs\glassdoor_scrape\lib\site-packages (from pandas>=0.23->seaborn) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\brand\anaconda3\envs\glassdoor_scrape\lib\site-packages (from python-dateutil>=2.7->matplotlib>=2.2->seaborn) (1.16.0)
# Installing collected packages: scipy, seaborn
# Successfully installed scipy-1.8.1 seaborn-0.11.2

# %%
test = pd.read_csv('C:/Users/brand/OneDrive/Documents/GitHub/ds_comrev_capstone/tencent_reviews.csv')

# %%
pd.set_option('display.width', 999)

# %%
test
# Out:
#                   employee_title             location employee_status  \
# 0              Frontend Engineer            Singapore    12 May 2022
# 1       Senior Software Engineer            Singapore    19 May 2022
# 2              Software Engineer                  NaN     5 May 2022
# 3                        Manager                  NaN    27 Apr 2022
# 4                  Senior Artist                  NaN     8 Apr 2022
# ..                           ...                  ...             ...
# 495   Investor Reporting Analyst      London, England    18 Dec 2020
# 496                       Intern                  NaN     6 Jan 2021
# 497            Software Engineer  Shenzhen, Guangdong    19 Dec 2020
# 498              Human Resources                  NaN    18 Dec 2020
# 499            Software Engineer                  NaN    31 Dec 2020
#
#                                  review_title  \
# 0                                Good welfare
# 1     Good place and good people to work with
# 2      Your lack of planning is not my crisis
# 3                  Toss you away like garbage
# 4    tencent is the dream from my younger age
# ..                                        ...
# 495                                     great
# 496                                    review
# 497                                      good
# 498                                  Internet
# 499         Leading Internet Company in China
#
#                                                   pros  \
# 0               Good welfare and culture. I like it!\n
# 1    flexible, remote-able, challenging, friendly. ...
# 2    Good compensation.\nGood welfare.\nGood exposu...
# 3    Good benefits (comparing to their Chinese coun...
# 4    Resource , tech support, good income, have it'...
# ..                                                 ...
# 495                          a best job on the world\n
# 496           salary is ok, snack, sports facilities\n
# 497           potential to grow, able to learn a lot\n
# 498                        Team work happy high paid\n
# 499  Dominant market position in IM, social network...
#
#                                                   cons  rating_overall
# 0    Communication with mainland China is required....             5.0
# 1    no work balance. too many Chinese. no English ...             4.0
# 2    Minimum planning, maximum firefighting.\nProje...             2.0
# 3    CFO said there won’t be layoffs during industr...             2.0
# 4    Need to be more international.\n1 person found...             5.0
# ..                                                 ...             ...
# 495  i don't think there are any cons\n1 person fou...             5.0
# 496  there are some genius, stressful\nBe the first...             3.0
# 497  too busy, poor work life balance\nBe the first...             5.0
# 498  Pressure Competition High pace tired\nBe the f...             5.0
# 499  Bad infrastruacture for R&D, weak tech accumul...             4.0
#
# [500 rows x 7 columns]

# %%
def clean_text_cons(text):
    # remove the text that is not part of the actual comments
    pattern1 = re.compile(r'\nBe\sthe\sfirst.+')
    text = pattern1.sub(r'',text)
    pattern2 = re.compile(r'\d\speople\sfound\sthis.+')
    text = pattern2.sub(r'',text)
    pattern3 = re.compile(r'\d\sperson\sfound.+')
    text = pattern3.sub(r'',text)
    pattern4 = re.compile(r'\nHelpful\nShare\nRepor')
    text = pattern4.sub(r'',text)
    
    # remove "/n"
    pattern5 = re.compile(r'\n')
    text = pattern5.sub(r'',text)
    # remove irrelevant character such as numbers and punctuation
    pattern6 = re.compile(r'[^a-zA-Z0-9]')
    text = pattern6.sub(r' ',text)
    # remove extra whitespaces
    pattern7= re.compile(r'^\s*|\s\s*')
    text = pattern7.sub(r' ', text).strip()
    # text to all lower case
    text = text.lower()
    
    return text

# %%
test['cons_final'] = test['cons'].map(lambda x: clean_text_cons(x))

# %%
def clean_text_pros(text):
    # remove "/n"
    pattern1 = re.compile(r'\n')
    text = pattern1.sub(r'',text)
    # remove irrelevant character such as numbers and punctutation
    pattern2 = re.compile(r'[^a-zA-Z0-9]')
    text = pattern2.sub(r' ',text)
    # remove extra whitespaces
    pattern3 = re.compile(r'^\s*|\s\s*')
    text = pattern3.sub(r' ', text).strip()
    # text to all lower case
    text = text.lower()
    return text

# %%
test['pros_final'] = test['pros'].map(lambda x: clean_text_pros(str(x)))

# %%
test.sample(50)
# Out:
#                          employee_title             location employee_status  \
# 258                  Technical Animator  Shenzhen, Guangdong    25 Oct 2021
# 27                     Senior Recruiter            Singapore    29 Jul 2021
# 156                       Web Developer                  NaN    16 Feb 2022
# 406                           Anonymous     Beijing, Beijing    18 Apr 2021
# 471                        Data Analyst  Shenzhen, Guangdong    20 Jan 2021
# 83               Senior Project Manager  Shenzhen, Guangdong    12 Apr 2022
# 116                   Software Engineer                  NaN     8 Apr 2022
# 58                   Operations Manager                  NaN    14 May 2022
# 304                    Mobile Developer  Shenzhen, Guangdong    8 Sept 2021
# 129                   Software Engineer  Shenzhen, Guangdong    29 Mar 2022
# 141        Media Advertising Consultant  Shenzhen, Guangdong    27 Feb 2022
# 192                          Recruiting            Hong Kong    24 Jan 2022
# 212                           Anonymous        San Diego, CA     5 Jan 2022
# 294                      Level Designer  Shenzhen, Guangdong     6 Oct 2021
# 190                       Game Designer                  NaN    12 Jan 2022
# 454                     Project Manager   Shanghai, Shanghai     5 Mar 2021
# 64                       Data Scientist  Shenzhen, Guangdong    12 May 2022
# 61                 Senior IOS Developer                  NaN    13 May 2022
# 187                          Internship                  NaN    17 Jan 2022
# 252                       Game Designer  Shenzhen, Guangdong    11 Nov 2021
# 127                  Security Engineer    Shanghai, Shanghai    30 Mar 2022
# 81                   Front End Engineer                  NaN    17 Apr 2022
# 433                           Anonymous                  NaN    22 Mar 2021
# 47                 Marketing Specialist              Bangkok    14 May 2022
# 479            Senior Software Engineer  Shenzhen, Guangdong     9 Jan 2021
# 332          Talent Development Manager                  NaN     5 Aug 2021
# 63    Global Campus Recruitment Manager                  NaN    28 Apr 2022
# 371                Social Media Manager                  NaN    28 May 2021
# 169                    Business Analyst     Beijing, Beijing     3 Feb 2022
# 106                              Intern            Hong Kong    31 Mar 2022
# 402                          Programmer                  NaN     6 May 2021
# 358                     Human Resources   Shanghai, Shanghai    23 Jul 2021
# 23                              Manager                  NaN   27 Sept 2021
# 42                            Anonymous                  NaN    21 Aug 2017
# 69             Senior Software Engineer   Shanghai, Shanghai     9 May 2022
# 210                  Sofetware Engineer         New York, NY     5 Jan 2022
# 26                    Software Engineer            Singapore    31 Aug 2021
# 306              Product Manager Intern  Shenzhen, Guangdong    8 Sept 2021
# 296                          Internship  Shenzhen, Guangdong     4 Oct 2021
# 124               Data Analysis Manager                  NaN    31 Mar 2022
# 419                        Data Analyst  Shenzhen, Guangdong     7 Apr 2021
# 491            Junior Software Engineer  Shenzhen, Guangdong    10 Jan 2021
# 318                           Anonymous                  NaN    3 Sept 2021
# 146              Senior Product Manager                  NaN    10 Mar 2022
# 223                  Tencent MA Analyst     Beijing, Beijing     8 Dec 2021
# 76                      Account Manager                  NaN     5 May 2022
# 86           User Experience Researcher                  NaN    13 Apr 2022
# 273                        Data Analyst  Shenzhen, Guangdong    12 Oct 2021
# 184                           Anonymous                  NaN    24 Jan 2022
# 325                           Anonymous                  NaN    28 Aug 2021
#
#                                           review_title  \
# 258                          working for Tencent Games
# 27   The Chinese Tech Company that cares for it's e...
# 156                                               test
# 406                             Best employer in China
# 471                                      cant complain
# 83                        Impressive Woring Experience
# 116  Really depends on which team you are in and wh...
# 58                       Good benefits, bad management
# 304                                           Good Job
# 129                                 overall evaluation
# 141                                   Really great job
# 192                                                123
# 212                                            average
# 294                               Good choice in China
# 190                                                124
# 454                                               work
# 64                                   Review of Tencent
# 61                                                   1
# 187                                                NaN
# 252                           Tencent TIMI J6 workshop
# 127                                              happy
# 81                                                nice
# 433                 Tencent is generally a good choice
# 47                                          Great team
# 479                                        Recommended
# 332                                company environment
# 63                         Great experience at Tencent
# 371                                               good
# 169                                             123345
# 106                     Great company, Nice Colleagues
# 402                                               Work
# 358                                              crazy
# 23                                           Employees
# 42                         good environment and people
# 69                   Tencent is a good option in China
# 210                               no work life balance
# 26                                            engineer
# 306  The company atmosphere is good, no push, but t...
# 296                                        Internshipp
# 124                best culture in Chinese tech giants
# 419                                  Data Science Team
# 491                                         Just a job
# 318                                            Not bad
# 146                                                  p
# 223                                    Very good place
# 76                                       Good employer
# 86                                            Big Tech
# 273                                               Good
# 184                                      Great Company
# 325                                    Jobdesk Unclear
#
#                                                   pros  \
# 258                 good money and incentives indeed\n
# 27   - great company values and indeed they practic...
# 156     good people and have Good salary and welfare\n
# 406  Great facility and benefits. We have a gym, ba...
# 471                 lay back atmosphere mostly maybe\n
# 83         Multiple Opportunities in various fields.\n
# 116          Competitive package. Big tech in China.\n
# 58   Its a good company with good benefits and a lo...
# 304        Free Culture, good policy, good colleges.\n
# 129  flexible working hours, benifits.\nWLB when co...
# 141                                                NaN
# 192   leading apps in China \nstable business growth\n
# 212                 have dencent salary for new grad\n
# 294  Biggest game company in china, a lot of oppert...
# 190                   Nice 1235 work and nice salary\n
# 454                          Job pays very very well\n
# 64         Good atmosphere\ngood benefits and salary\n
# 61                       maybe strong work sigl weig\n
# 187      Provide great opportunities for new joiners\n
# 252  very complete working pipeline and business lo...
# 127            Strong technical atmosphere and happy\n
# 81     big platform, better welfare, lead technology\n
# 433  elastic working hours;\ndecent pay;\nreally ni...
# 47   People are very nice, friendly and helpful. Go...
# 479                    Cool style, RSU, Good culture\n
# 332         nicely working environment for employees\n
# 63   Amazing work atmosphere\nFlexible working hour...
# 371                           nice soooo good at all\n
# 169  patience, modesty, hard working, reasoning ski...
# 106  Fruitful learning resources, Friendly colleagu...
# 402             A lot of Money . Pro mobile game dev\n
# 358  crazy management style, no line between work a...
# 23               The high salary and promotive works\n
# 42   good salary, very stable platform to try what ...
# 69   Free breakfast & dinner\nFree bus\nTop 1 tech ...
# 210    using C++ / C \nLinux\nbackend\nserver mostly\n
# 26   it's for new grad. u can find a not bad job wh...
# 306                Salary is high with good benefits\n
# 296     good place to learn skills and new knewledge\n
# 124  -best culture among Chinese internet companies...
# 419                  The work life balance is better\n
# 491  Big name in China.\nHigh Salary (But not the h...
# 318            A lot of reporting but good benefits.\n
# 146                   lots of money,funny people and\n
# 223                   nice culture, very nice people\n
# 76   handsome payment\nwell-structured organization...
# 86   Big Tech Company with redundant resources you ...
# 273              Great company, good culture overall\n
# 184  Culture is amazing\nAlways learning\nFailure i...
# 325               - Good work ethic\n- Good facility\n
#
#                                                   cons  rating_overall  \
# 258  factory style working environment at large\nBe...             5.0
# 27   - too bad we can't really work in office and m...             5.0
# 156  Serious overtime, have no time to rest\nBe the...             5.0
# 406  frequent organizational changes\nslow decision...             5.0
# 471  not so lay back atcually\nBe the first to find...             5.0
# 83   Sometimes overwork a little bit\nBe the first ...             5.0
# 116  If your team is not working on the core produc...             3.0
# 58   Main issue lies in the director level manageme...             4.0
# 304  Unstable project, don’t like the drink culture...             5.0
# 129  Frequent reorg of non-core businesses, PIP.\nB...             4.0
# 141  ltant in Shenzhen, Guangdong\nRecommend\nCEO A...             5.0
# 192  working overtime\nlacking innovations in the p...             3.0
# 212  sometimes you have to work overtime\nBe the fi...             4.0
# 294  996, work overtime. \nmost projects lack innov...             4.0
# 190  Too much work I no load\nBe the first to find ...             5.0
# 454  Overtime is about 80 hours a week\n1 person fo...             2.0
# 64   No significant cons. I am satisfied\nBe the fi...             4.0
# 61   not good of work life balance\nBe the first to...             4.0
# 187  Couldn't think of any cons\nBe the first to fi...             5.0
# 252  late finish time, almost over my job 9PM each ...             4.0
# 127  no no no no no\nBe the first to find this revi...             4.0
# 81   busy, \nlack of promotion,\nlack of wlb\nBe th...             5.0
# 433  The working hour is too long in some departmen...             5.0
# 47   Due to the company is a global co., so some pr...             5.0
# 479  Work over time time sometimes\nBe the first to...             5.0
# 332  too much communication as so many stakeholders...             5.0
# 63   not quite well known internationally\nBe the f...             5.0
# 371  I loveee it and and coool\nBe the first to fin...             5.0
# 169  lack of professional experience, needs more wo...             5.0
# 106  relatively demanding, the pace is fast\nBe the...             5.0
# 402  A lot of work too long work time\nBe the first...             3.0
# 358  crazy culture and management, no ethics and re...             1.0
# 23   The long working hours in the tencent\n1 perso...             4.0
# 42   too stable, the organization is becoming less ...             5.0
# 69   work life imbalance\nhigh apartment price in S...             4.0
# 210  hi this is d d\n2 people found this review hel...             4.0
# 26   too many works. boss is very push.\n1 person f...             3.0
# 306  Too tired, 10 10 5, the content of job is non-...             5.0
# 296  stress and anxious working environment\nBe the...             4.0
# 124  - not the best pay in the industry \n- ToB bus...             4.0
# 419  Our team seems not very good\nBe the first to ...             5.0
# 491  Poor tech infrastructure.\nLong work time, abo...             3.0
# 318  Too much reporting and internal politics\nBe t...             4.0
# 146  bad environments and lost if cats\nBe the firs...             4.0
# 223  heavy workload, too little sleep\nBe the first...             5.0
# 76   hard to get promotion\nparty conflict\nBe the ...             4.0
# 86   complex organizational procedures that can con...             5.0
# 273  not at the moment .\nBe the first to find this...             5.0
# 184  None that I can think of\nBe the first to find...             5.0
# 325  - Indonesian office function is more like agen...             2.0
#
#                                             cons_final  \
# 258         factory style working environment at large
# 27   too bad we can t really work in office and mee...
# 156              serious overtime have no time to rest
# 406  frequent organizational changesslow decision m...
# 471                           not so lay back atcually
# 83   sometimes overwork a little bitttencent respon...
# 116  if your team is not working on the core produc...
# 58   main issue lies in the director level manageme...
# 304  unstable project don t like the drink culture ...
# 129  frequent reorg of non core businesses pip tten...
# 141  ltant in shenzhen guangdongrecommendceo approv...
# 192  working overtimelacking innovations in the pas...
# 212  sometimes you have to work overtimettencent re...
# 294    996 work overtime most projects lack innovation
# 190                            too much work i no load
# 454                  overtime is about 80 hours a week
# 64   no significant cons i am satisfiedttencent res...
# 61                       not good of work life balance
# 187                         couldn t think of any cons
# 252   late finish time almost over my job 9pm each day
# 127                                     no no no no no
# 81                  busy lack of promotion lack of wlb
# 433   the working hour is too long in some departments
# 47   due to the company is a global co so some proj...
# 479                      work over time time sometimes
# 332  too much communication as so many stakeholders...
# 63   not quite well known internationallyttencent r...
# 371                          i loveee it and and coool
# 169  lack of professional experience needs more wor...
# 106  relatively demanding the pace is fastttencent ...
# 402                   a lot of work too long work time
# 358  crazy culture and management no ethics and res...
# 23               the long working hours in the tencent
# 42   too stable the organization is becoming less flat
# 69   work life imbalancehigh apartment price in sha...
# 210  hi this is d dttencent responsethanks for your...
# 26                    too many works boss is very push
# 306  too tired 10 10 5 the content of job is non te...
# 296             stress and anxious working environment
# 124  not the best pay in the industry tob business ...
# 419                       our team seems not very good
# 491  poor tech infrastructure long work time about ...
# 318           too much reporting and internal politics
# 146                  bad environments and lost if cats
# 223                    heavy workload too little sleep
# 76                 hard to get promotionparty conflict
# 86   complex organizational procedures that can con...
# 273                                  not at the moment
# 184                           none that i can think of
# 325  indonesian office function is more like agency...
#
#                                             pros_final
# 258                   good money and incentives indeed
# 27   great company values and indeed they practiced...
# 156       good people and have good salary and welfare
# 406  great facility and benefits we have a gym bask...
# 471                   lay back atmosphere mostly maybe
# 83            multiple opportunities in various fields
# 116              competitive package big tech in china
# 58   its a good company with good benefits and a lo...
# 304             free culture good policy good colleges
# 129  flexible working hours benifits wlb when compa...
# 141                                                nan
# 192       leading apps in china stable business growth
# 212                   have dencent salary for new grad
# 294  biggest game company in china a lot of oppertu...
# 190                     nice 1235 work and nice salary
# 454                            job pays very very well
# 64             good atmospheregood benefits and salary
# 61                         maybe strong work sigl weig
# 187        provide great opportunities for new joiners
# 252  very complete working pipeline and business lo...
# 127              strong technical atmosphere and happy
# 81         big platform better welfare lead technology
# 433  elastic working hours decent pay really nice b...
# 47   people are very nice friendly and helpful good...
# 479                        cool style rsu good culture
# 332           nicely working environment for employees
# 63   amazing work atmosphereflexible working hoursg...
# 371                             nice soooo good at all
# 169     patience modesty hard working reasoning skills
# 106  fruitful learning resources friendly colleague...
# 402                 a lot of money pro mobile game dev
# 358  crazy management style no line between work an...
# 23                 the high salary and promotive works
# 42   good salary very stable platform to try what y...
# 69   free breakfast dinnerfree bustop 1 tech compan...
# 210                using c c linuxbackendserver mostly
# 26   it s for new grad u can find a not bad job whe...
# 306                  salary is high with good benefits
# 296       good place to learn skills and new knewledge
# 124  best culture among chinese internet companies ...
# 419                    the work life balance is better
# 491  big name in china high salary but not the highest
# 318               a lot of reporting but good benefits
# 146                     lots of money funny people and
# 223                      nice culture very nice people
# 76   handsome paymentwell structured organizationgo...
# 86   big tech company with redundant resources you ...
# 273                 great company good culture overall
# 184  culture is amazingalways learningfailure is a ...
# 325                      good work ethic good facility

# %%
import matplotlib.pyplot as plt
test['location'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   employee_title   500 non-null    object
#  1   location         306 non-null    object
#  2   employee_status  500 non-null    object
#  3   review_title     496 non-null    object
#  4   pros             498 non-null    object
#  5   cons             500 non-null    object
#  6   rating_overall   500 non-null    float64
#  7   cons_final       500 non-null    object
#  8   pros_final       500 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 35.3+ KB

# %%
test['employee_status'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
