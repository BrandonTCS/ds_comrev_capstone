# %% [markdown]
# ## NLP with company reviews on Glassdoor
#
# This capstone project is about helping companies/potential employee identify potential problems within a company. The business focus will be to help potential clients/companies get insights into the problems that existing or past employees faced within the company to reduce the turnover rate, solve potential mental health issues of employees and improve the image of the company. This could also assist the ministry of manpower or ministry with complaints filed by employees on employers for misconduct on determining if such issues has been flagged by other employees of the companies. These are just some of the use case of this project but not just limited to only the use case mentioned above.

# %% [markdown]
# #### Credit to Mathew Chatham for the scraper
# This is to credit Matthew Chatham for the scraper in which he had created and shared on github. The scraper could not work immediately as the codes on glassdoor has changed over the time of 2 -3 years which he created the scraper. Some tweaks was done to update and remove fields that are not required. The link can be found here (https://github.com/MatthewChatham/glassdoor-review-scraper)

# %%
import selenium
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
import seaborn as sns
import re
import spacy
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %% [markdown]
# ## Data Extraction
#
# ### Using the scraper to obtain the data and putting it into a DataFrame

# %%
# using the code by Matthew after some updates was done to get the scraper to work

# this is to scrape 500 reviews from glassdoor of Tencent a china internet company
# %run main.py --url "https://www.glassdoor.sg/Reviews/Tencent-Reviews-E38281.htm" --limit 500 -f tencent_reviews.csv

# %%
# this is to scrape 500 reviews from glassdoor of Google a US internet company
# %run main.py --url "https://www.glassdoor.sg/Reviews/Google-Reviews-E9079.htm" --limit 500 -f google_reviews.csv

# %%
# reading the csv file and assign the data to a variable in a dataframe
tencent_df = pd.read_csv('tencent_reviews.csv')
google_df = pd.read_csv('google_reviews.csv')

# %%
tencent_df.sample(10)
# Out:
#            employee_title             location employee_status  \
# 264               Analyst  Shenzhen, Guangdong    17 Oct 2021
# 145       Human Resources     Beijing, Beijing    10 Mar 2022
# 368   Marketing Assistant                Paris    18 Jun 2021
# 156         Web Developer                  NaN    16 Feb 2022
# 262     Software Engineer  Shenzhen, Guangdong    18 Oct 2021
# 482      Business Analyst                  NaN    20 Jan 2021
# 94    Computer Programmer                  NaN    22 Apr 2022
# 288    Applied Researcher  Shenzhen, Guangdong   24 Sept 2021
# 430       Product Manager  Shenzhen, Guangdong    25 Mar 2021
# 64         Data Scientist  Shenzhen, Guangdong    12 May 2022
#
#                           review_title  \
# 264  Good company to kick off a career
# 145                                  -
# 368      creative,quickly,nice company
# 156                               test
# 262                              great
# 482        Overall it's a good company
# 94             Computer game developer
# 288                             AI Lab
# 430    good company with great culture
# 64                   Review of Tencent
#
#                                                   pros  \
# 264  A Good company with aspiring future; good atmo...
# 145           Flexible, flat, and candid atmosphere.\n
# 368  It is a united, creative, and young company. B...
# 156     good people and have Good salary and welfare\n
# 262                    great place to work and learn\n
# 482   competitive salaries, cozy working environment\n
# 94   Master several programming language including ...
# 288  In AI Lab, the environment feels soft and comf...
# 430  good for new graduates to grow up, profound re...
# 64         Good atmosphere\ngood benefits and salary\n
#
#                                                   cons  rating_overall
# 264  Lack of personal fulfillment to some extent\nB...             5.0
# 145  NA, temporarily not found, but still has some ...             4.0
# 368  It is exclusive in some areas and has no compe...             4.0
# 156  Serious overtime, have no time to rest\nBe the...             5.0
# 262  work time is long and everyone takes it for gr...             5.0
# 482  too much politics, no creativity\nBe the first...             4.0
# 94   Normal communicating skill\nDo not want to ove...             4.0
# 288  Different department have different culture.\n...             5.0
# 430  too many departments in a big company, hard to...             5.0
# 64   No significant cons. I am satisfied\nBe the fi...             4.0

# %%
google_df.sample(10)
# Out:
#                                  employee_title               location  \
# 289                Digital Marketing Specialist              Singapore
# 146                                   Anonymous              Singapore
# 276                                   Anonymous                    NaN
# 321   Senior Security Specialist At Data Center  Jurong West New Town,
# 463                          Accounting Manager                    NaN
# 198                                  Internship              Singapore
# 324                                      Intern              Singapore
# 36                                      Partner                    NaN
# 42                                    Anonymous                    NaN
# 487                      Software Test Engineer                    NaN
#
#     employee_status                                       review_title  \
# 289    14 Oct 2020                                             Love it
# 146    11 Jul 2021                                           Google SG
# 276    14 Dec 2020                                              Review
# 321    25 Jun 2020   It is what not the hype you read in the news. ...
# 463    21 May 2022                                          Accounting
# 198    14 Apr 2021                                Software Engineering
# 324    14 May 2020                                         Pretty good
# 36     23 Feb 2022                                               great
# 42      7 Feb 2022                                                Good
# 487    20 May 2022                                   Excellent company
#
#                                                   pros  \
# 289     Like the food coffee people and work culture\n
# 146  Bright people, opportunity to innovate and wor...
# 276  Good culture, people and opportunities to deve...
# 321                                  B E N E F I T S\n
# 463                             Pay well for the job\n
# 198        Good work environment, helpful colleagues\n
# 324                Good food, modern tech facilities\n
# 36                            great place to work ..\n
# 42                         This company pays me well\n
# 487  compensation while working at google is very g...
#
#                                                   cons  rating_overall
# 289  Everything has to be read between the lines\nB...             5.0
# 146  Too many bright people, perf can be a blood sp...             4.0
# 276  nothing really bad or negative to comment\nBe ...             4.0
# 321  Global MNC but still local mentality with horr...             1.0
# 463  Can work long hours with those\nBe the first t...             5.0
# 198  no downsides from my experience\nBe the first ...             5.0
# 324  Not much to say la\nAdvice to Management\nGo\n...             3.0
# 36   nothing really to say really\nBe the first to ...             5.0
# 42   Hard to get in this company\nBe the first to f...             5.0
# 487  hard to progress career at google\nBe the firs...             5.0

# %% [markdown]
# ## Data Preprocessing
#
# ### Checking for nulls and datatype

# %%
tencent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   employee_title   500 non-null    object
#  1   location         306 non-null    object
#  2   employee_status  500 non-null    object
#  3   review_title     496 non-null    object
#  4   pros             498 non-null    object
#  5   cons             500 non-null    object
#  6   rating_overall   500 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 27.5+ KB

# %%
google_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   employee_title   485 non-null    object
#  1   location         280 non-null    object
#  2   employee_status  500 non-null    object
#  3   review_title     493 non-null    object
#  4   pros             484 non-null    object
#  5   cons             500 non-null    object
#  6   rating_overall   500 non-null    float64
# dtypes: float64(1), object(6)
# memory usage: 27.5+ KB

# %%
# changing datatype of column: employee_status
tencent_df['employee_status'] = tencent_df['employee_status'].astype('datetime64[ns]')
google_df['employee_status'] = google_df['employee_status'].astype('datetime64[ns]')

# %%
# check for nulls (tencent)
tencent_df.isnull().sum()
# Out:
# employee_title       0
# location           194
# employee_status      0
# review_title         4
# pros                 2
# cons                 0
# rating_overall       0
# dtype: int64

# %%
# check for nulls (google)
google_df.isnull().sum()
# Out:
# employee_title      15
# location           220
# employee_status      0
# review_title         7
# pros                16
# cons                 0
# rating_overall       0
# dtype: int64

# %%
# exploring the nulls in google employee title

google_df[google_df['employee_title'].isnull()]
# Out:
#     employee_title      location employee_status  \
# 379            NaN           NaN      2018-10-26
# 408            NaN           NaN      2017-04-10
# 410            NaN           NaN      2017-02-23
# 418            NaN           NaN      2016-10-01
# 422            NaN           NaN      2016-05-08
# 425            NaN  New York, NY      2016-02-14
# 426            NaN           NaN      2016-01-28
# 427            NaN           NaN      2016-01-21
# 434            NaN           NaN      2015-08-14
# 445            NaN           NaN      2014-10-12
# 446            NaN           NaN      2014-10-10
# 448            NaN           NaN      2014-08-20
# 451            NaN           NaN      2014-01-07
# 453            NaN           NaN      2013-10-03
# 458            NaN           NaN      2013-03-13
#
#                                           review_title  \
# 379             Very Good working environment @ google
# 408                           My internship experience
# 410                                            Analyst
# 418    Pros and Cons - Just Like Any Other Big Company
# 422                             Selected for GSoC 2016
# 425                                 Great environment!
# 426                      Online Advertising Specialist
# 427                                   Business Manager
# 434         Excellent company with limitless potential
# 445                              Amazing place to work
# 446  Gd perks and great colleagues, fun loving and ...
# 448                                            Awesome
# 451         Great company. Excellent work environment.
# 453            All that glitters is not gold (YouTube)
# 458                            Industry analyst intern
#
#                                                   pros  \
# 379                          fun people to work with\n
# 408  - Diversity \n- Dynamic and helpful teams \n- ...
# 410                         Great Place to work at !\n
# 418                                               and
# 422  Adds value to your skillset and experience. Yo...
# 425  A place where people come together and produce...
# 426  Awesome people, great benefits and loads of op...
# 427      smart colleagues, great transparent culture\n
# 434  awesome food, awesome people, great benefits a...
# 445               Smart folks and great stuff to do.\n
# 446                  Good perks and great colleagues\n
# 448  Good work life balance. Plenty of room to grow.\n
# 451  Free food. Excellent office location. Smart & ...
# 453  All the usual (i) Lifestyle (ii) Perks (iii) F...
# 458          Best place to co-work and friendly mood\n
#
#                                                   cons  rating_overall
# 379  work can be stressful at times\nBe the first t...             5.0
# 408  - sometimes you have short time to socialise w...             5.0
# 410  Nothing that i can think of\nAdvice to Managem...             5.0
# 418  - Just Like Any Other Big Company\n1 Oct 2016 ...             3.0
# 422  Should send at least two t-shirts and more goo...             5.0
# 425  Needs more people to execute at times\nAdvice ...             4.0
# 426  It is not the best place to get promoted fast\...             5.0
# 427  extremely competitive, harder to advance given...             5.0
# 434  everything revolves around Mountain View. hard...             5.0
# 445  long hours, pay is okay and could be higher\nB...             5.0
# 446  Night calls all the time\nAdvice to Management...             4.0
# 448  Salary not too attractive. That said, benefits...             4.0
# 451  Long days, working for global company means mu...             4.0
# 453  I work at YouTube. It is run like an army camp...             1.0
# 458  it does not have any defects\nBe the first to ...             5.0

# %%
'''from the above, we can see that some of the null values of employee title can be found in the review title. So we will fill
the employee titles of these'''

# index no (408, 410, 426, 427, 458) impute with position found in review title

google_df.iloc[408, google_df.columns.get_loc('employee_title')] = 'Intern'
google_df.iloc[410, google_df.columns.get_loc('employee_title')] = 'Analyst'
google_df.iloc[426, google_df.columns.get_loc('employee_title')] = 'Online Advertising Specialist'
google_df.iloc[427, google_df.columns.get_loc('employee_title')] = 'Business Manager'
google_df.iloc[458, google_df.columns.get_loc('employee_title')] = 'Industry Analyst Intern'

# %%
# remaining nulls in employee title after imputing the title
google_df[google_df['employee_title'].isnull()]
# Out:
#     employee_title      location employee_status  \
# 379            NaN           NaN      2018-10-26
# 418            NaN           NaN      2016-10-01
# 422            NaN           NaN      2016-05-08
# 425            NaN  New York, NY      2016-02-14
# 434            NaN           NaN      2015-08-14
# 445            NaN           NaN      2014-10-12
# 446            NaN           NaN      2014-10-10
# 448            NaN           NaN      2014-08-20
# 451            NaN           NaN      2014-01-07
# 453            NaN           NaN      2013-10-03
#
#                                           review_title  \
# 379             Very Good working environment @ google
# 418    Pros and Cons - Just Like Any Other Big Company
# 422                             Selected for GSoC 2016
# 425                                 Great environment!
# 434         Excellent company with limitless potential
# 445                              Amazing place to work
# 446  Gd perks and great colleagues, fun loving and ...
# 448                                            Awesome
# 451         Great company. Excellent work environment.
# 453            All that glitters is not gold (YouTube)
#
#                                                   pros  \
# 379                          fun people to work with\n
# 418                                               and
# 422  Adds value to your skillset and experience. Yo...
# 425  A place where people come together and produce...
# 434  awesome food, awesome people, great benefits a...
# 445               Smart folks and great stuff to do.\n
# 446                  Good perks and great colleagues\n
# 448  Good work life balance. Plenty of room to grow.\n
# 451  Free food. Excellent office location. Smart & ...
# 453  All the usual (i) Lifestyle (ii) Perks (iii) F...
#
#                                                   cons  rating_overall
# 379  work can be stressful at times\nBe the first t...             5.0
# 418  - Just Like Any Other Big Company\n1 Oct 2016 ...             3.0
# 422  Should send at least two t-shirts and more goo...             5.0
# 425  Needs more people to execute at times\nAdvice ...             4.0
# 434  everything revolves around Mountain View. hard...             5.0
# 445  long hours, pay is okay and could be higher\nB...             5.0
# 446  Night calls all the time\nAdvice to Management...             4.0
# 448  Salary not too attractive. That said, benefits...             4.0
# 451  Long days, working for global company means mu...             4.0
# 453  I work at YouTube. It is run like an army camp...             1.0

# %%
# as for the other missing employee title, we will instead fillna as "Anonymous"
google_df['employee_title'].fillna('Anonymous', inplace = True)

# %%
# check if there is any more nulls in employee title
google_df[google_df['employee_title'].isnull()]
# Out:
# Empty DataFrame
# Columns: [employee_title, location, employee_status, review_title, pros, cons, rating_overall]
# Index: []

# %%
# using SimpleImputer with strategy set to most_frequent to impute NaN location to the most common

imputer = SimpleImputer(strategy='most_frequent')
google_df['location'] = imputer.fit_transform(google_df[['location']])
tencent_df['location'] = imputer.fit_transform(tencent_df[['location']])

# %%
# setting up a new column for only year of the review
tencent_df['review_year'] = pd.DatetimeIndex(tencent_df['employee_status']).year
google_df['review_year'] = pd.DatetimeIndex(google_df['employee_status']).year

# %%
# removing employee_status (exact date of the review)

tencent_df.drop(columns='employee_status', inplace=True)
google_df.drop(columns='employee_status', inplace=True)

# %%
# fill text columns that have nan as blank
tencent_df['review_title'].fillna('', inplace=True)
google_df['review_title'].fillna('', inplace=True)

tencent_df['pros'].fillna('', inplace=True)
google_df['pros'].fillna('', inplace=True)

# %%
tencent_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   employee_title  500 non-null    object
#  1   location        500 non-null    object
#  2   review_title    500 non-null    object
#  3   pros            500 non-null    object
#  4   cons            500 non-null    object
#  5   rating_overall  500 non-null    float64
#  6   review_year     500 non-null    int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 27.5+ KB

# %%
google_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   employee_title  500 non-null    object
#  1   location        500 non-null    object
#  2   review_title    500 non-null    object
#  3   pros            500 non-null    object
#  4   cons            500 non-null    object
#  5   rating_overall  500 non-null    float64
#  6   review_year     500 non-null    int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 27.5+ KB

# %% [markdown]
# ## Exploratory Data Analysis
# ### Ratings

# %%
# looking ratings of the review

tencent_df['rating_overall'].value_counts(normalize=True).sort_index(level='rating_overall', ascending=False).plot(kind='bar')
plt.title('Tecent Ratings')
plt.xlabel('Ratings')
plt.ylabel('Number of Ratings')
# Out:
# Text(0, 0.5, 'Number of Ratings')

# %%
# the distribution of 5.0 + 4.0 ratings
tencent_df['rating_overall'].value_counts(normalize=True).sort_index(level='rating_overall', ascending=False)
# Out:
# 5.0    0.468
# 4.0    0.338
# 3.0    0.114
# 2.0    0.038
# 1.0    0.042
# Name: rating_overall, dtype: float64

# %%
google_df['rating_overall'].value_counts(normalize=True).sort_index(level='rating_overall', ascending=False).plot(kind='bar')
plt.title('Google Ratings')
plt.xlabel('Ratings')
plt.ylabel('Number of Ratings')
# Out:
# Text(0, 0.5, 'Number of Ratings')

# %%
google_df['rating_overall'].value_counts(normalize=True).sort_index(level='rating_overall', ascending=False)
# Out:
# 5.0    0.672
# 4.0    0.208
# 3.0    0.084
# 2.0    0.012
# 1.0    0.024
# Name: rating_overall, dtype: float64

# %% [markdown]
# #### Google had a better rating score at 88% of score between 4 - 5 compared to Tencent at 80.6% of score between 4 - 5

# %% [markdown]
# ###  Employee Title

# %%
# Tencent Employee Title
tencent_df['employee_title'].value_counts().head(10).plot(kind='barh')
plt.title('Tencent Top 10 Employee Title')
plt.xlabel('Count')
# Out:
# Text(0.5, 0, 'Count')

# %%
# Google Employee Title
google_df['employee_title'].value_counts().head(10).plot(kind='barh')
plt.title('Google Top 10 Employee Title')
plt.xlabel('Count')
# Out:
# Text(0.5, 0, 'Count')

# %% [markdown]
# ### Location

# %%
# tencent location
tencent_df['location'].value_counts().head(10).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
# google location
google_df['location'].value_counts().head(10).plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Year of written review

# %%
# written reviews over the years (tencent)
tencent_df['review_year'].value_counts().sort_index(level='review_year', ascending=False).plot(kind='bar')
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Tencent reviews over the years')
# Out:
# Text(0.5, 1.0, 'Tencent reviews over the years')

# %%
# written reviews over the years (google)
google_df['review_year'].value_counts().sort_index(level='review_year', ascending=False).plot(kind='bar')
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Google reviews over the years')
# Out:
# Text(0.5, 1.0, 'Google reviews over the years')

# %% [markdown]
# #### Google started having reviews earlier than Tencent understandably as it is a English platform. Tencent only started their presence in 2016, 3 years later than Google.

# %% [markdown]
# # Pre-processing part 2
# ## Cleaning the text of unecessary words or symbols, lower case all the words

# %%
# helper function to clean the data for 

def clean_text(text):
    # remove the text that is not part of the actual comments
    pattern1 = re.compile(r'\nBe\sthe\sfirst.+')
    text = pattern1.sub(r'',text)
    pattern2 = re.compile(r'\d\speople\sfound\sthis.+')
    text = pattern2.sub(r'',text)
    pattern3 = re.compile(r'\d\sperson\sfound.+')
    text = pattern3.sub(r'',text)
    pattern4 = re.compile(r'\nHelpful\nShare\nRepor')
    text = pattern4.sub(r'',text)
    
    # remove "/n"
    pattern5 = re.compile(r'\n')
    text = pattern5.sub(r'',text)
    # remove irrelevant character such as numbers and punctuation
    pattern6 = re.compile(r'[^a-zA-Z0-9]')
    text = pattern6.sub(r' ',text)
    # remove extra whitespaces
    pattern7= re.compile(r'^\s*|\s\s*')
    text = pattern7.sub(r' ', text).strip()
    # text to all lower case
    text = text.lower()
    
    return text

# %%
# running the helper function to clean both google and tencent dataset

tencent_df['pros'] = tencent_df['pros'].apply(lambda x: clean_text(str(x)))
google_df['pros'] = google_df['pros'].apply(lambda x: clean_text(str(x)))

tencent_df['cons'] = tencent_df['cons'].apply(lambda x: clean_text(str(x)))
google_df['cons'] = google_df['cons'].apply(lambda x: clean_text(str(x)))

# %%
tencent_df.sample(10)
# Out:
#                                         employee_title             location  \
# 467                                    Project Manager     Chengdu, Sichuan
# 372                                           Director            Hong Kong
# 371                               Social Media Manager  Shenzhen, Guangdong
# 276                                            Manager            Hong Kong
# 155                            Digital Content Manager      London, England
# 173                                      Brand Manager  Shenzhen, Guangdong
# 339                                  2D Concept Artist  Shenzhen, Guangdong
# 80                                           Anonymous  Shenzhen, Guangdong
# 432                                  Software Engineer  Shenzhen, Guangdong
# 396   Chief Operation Officer (Chief Operating Offi...     Beijing, Beijing
#
#                                           review_title  \
# 467                                        pay is good
# 372                                   Top tech company
# 371                                               good
# 276                                            Love it
# 155                                   Great experience
# 173                    Great to join at a senior level
# 339                                          Work load
# 80                                        nice company
# 432                                             hahaha
# 396  The Company is a startup Company focused on tr...
#
#                                                   pros  \
# 467       high pay learn a lotcompetitive for next job
# 372                  tons of resources smart employees
# 371                             nice soooo good at all
# 276  very learning encouraged environment in each team
# 155                 salary is good people are friendly
# 173            wide portfolio of products to look over
# 339      good salary nice location free transportation
# 80                             tech giant to work with
# 432  professionalism responsibility team meaning do...
# 396  the company has great potentials in the growin...
#
#                                                   cons  rating_overall  \
# 467               strong pressure often work over time             5.0
# 372  slow reaction to the marketadvice to managemen...             4.0
# 371                          i loveee it and and coool             5.0
# 276  very competitive but indeed well rewardedttenc...             4.0
# 155  always under a high level of pressure ttencent...             5.0
# 173  difficult to work as a foreigner unless you sp...             3.0
# 339  always work over time without any over time pa...             2.0
# 80                          nothing yet to know or say             5.0
# 432       insufficient innovation not proactive enough             5.0
# 396        currently thew company is a startup company             5.0
#
#      review_year
# 467         2021
# 372         2021
# 371         2021
# 276         2021
# 155         2022
# 173         2022
# 339         2021
# 80          2022
# 432         2021
# 396         2021

# %%
google_df.sample(10)
# Out:
#             employee_title   location  \
# 268               Business  Singapore
# 322              Anonymous  Singapore
# 251        Human Resources  Singapore
# 59               Recruiter  Singapore
# 152                Manager  Singapore
# 456                Analyst  Singapore
# 95    Software Engineer II  Singapore
# 409              Anonymous  Singapore
# 370              Anonymous  Singapore
# 288        Sales Associate  Singapore
#
#                                           review_title  \
# 268                                        it was okay
# 322                                      Good Employer
# 251                                    Awesome company
# 59   Great Brand Name and Benefits, ALOT OF CONS to...
# 152                                                 Na
# 456                       The best company to work for
# 95            Interesting work, good work life balance
# 409                                  Software engineer
# 370                                      A Happy Place
# 288                                      Great culture
#
#                                                   pros  \
# 268                    the environment was okay so far
# 322  salary usually higher than market average work...
# 251           great culture smart people good benefits
# 59   great benefits and insurance coverage it s lik...
# 152                            its a very good company
# 456  extremely people oriented great perks big focu...
# 95   good working hours lots of other benefits heal...
# 409                    very creative and driven people
# 370            brilliant people flexible work schedule
# 288               great culture and good place to work
#
#                                                   cons  rating_overall  \
# 268  not much things to say depend on what s is you...             4.0
# 322  bureaucracy slow moving decision making and so...             5.0
# 251  high performance environment stressful competi...             5.0
# 59   company is a massive machine so decision makin...             1.0
# 152                     salary is below market average             4.0
# 456  could get slightly bureaucraticadvice to manag...             5.0
# 95                         as far as i know no problem             5.0
# 409                       not much cons here at google             5.0
# 370        demanding environment and often competitive             5.0
# 288             not many just a very large corporation             5.0
#
#      review_year
# 268         2021
# 322         2020
# 251         2021
# 59          2022
# 152         2021
# 456         2013
# 95          2021
# 409         2017
# 370         2019
# 288         2020

# %% [markdown]
# ## Tokenizing, removing stopwords, lemmatizing

# %%
pd.set_option('display.max_colwidth', 999)

# %%
# load spacy small english models
nlp = spacy.load('en_core_web_sm')

# %%
# function to remove stopwords
def remove_stopwords(text):
    text = [token for token in text if not token.is_stop]
    return text

# function to lemmatize
def lemmatize(text):
    text = [token.lemma_ for token in text]
    return text

# combine function to perform both removal stopwords and lemmatizing
def combine(text):
    text = remove_stopwords(text)
    text = lemmatize(text)
    return text

# %%
'''working on the pros column of the dataframe of both companies'''

# applying the spacy model to tokenize the sentence
google_df['pros'] = google_df['pros'].apply(lambda x: nlp(x))
tencent_df['pros'] = tencent_df['pros'].apply(lambda x: nlp(x))

# using the combine to do removal stopwords and lemmatizing
google_df['pros'] = google_df['pros'].apply(lambda x: combine(x))
tencent_df['pros'] = tencent_df['pros'].apply(lambda x: combine(x))

# list to string
google_df['pros'] = google_df['pros'].apply(lambda x: ' '.join(x))
tencent_df['pros'] = tencent_df['pros'].apply(lambda x: ' '.join(x))

'''working on the cons column of the dataframe of both companies'''

# applying the spacy model to tokenize the sentence
google_df['cons'] = google_df['cons'].apply(lambda x: nlp(x))
tencent_df['cons'] = tencent_df['cons'].apply(lambda x: nlp(x))

# using the combine to do removal stopwords and lemmatizing
google_df['cons'] = google_df['cons'].apply(lambda x: combine(x))
tencent_df['cons'] = tencent_df['cons'].apply(lambda x: combine(x))

# list to string
google_df['cons'] = google_df['cons'].apply(lambda x: ' '.join(x))
tencent_df['cons'] = tencent_df['cons'].apply(lambda x: ' '.join(x))

# %%
google_df.sample(10)
# Out:
#          employee_title         location  \
# 305            Engineer        Singapore
# 125             Planner  Bedok New Town,
# 158               Sales        Singapore
# 447           Anonymous        Singapore
# 476           Anonymous        Singapore
# 314         Field Sales        Singapore
# 406     Program Manager        Singapore
# 177           Executive        Singapore
# 191   Senior Consultant        Singapore
# 302       Sales Manager        Singapore
#
#                               review_title  \
# 305                   Maintain DC Business
# 125                 A monster of a company
# 158                                   Good
# 447  Awesome experience but happy to leave
# 476                                Awesome
# 314   Google Cloud != old idealised Google
# 406                   Was of great culture
# 177
# 191      Awesome place to grow your career
# 302                                  great
#
#                                                   pros  \
# 305              good enviroment flexible working time
# 125  google 1 great benefits2 organize good class t...
# 158                           good goos good good good
# 447  true great perk work life balance decent salar...
# 476                                cool place work imo
# 314  money interesting people glamour pageantry ves...
# 406  awesome benefit good multi national multi cult...
# 177                                         overall ok
# 191
# 302                                          great job
#
#                                                   cons  rating_overall  \
# 305                                   lot ot man power             4.0
# 125  feel like cog machineeverything optimize autom...             3.0
# 158       bad bad bad bad badadvice managementgood baf             3.0
# 447  big corporate daysadvice managementpromote peo...             4.0
# 476                                          bad place             5.0
# 314  old boy club shout loud inequity propel good w...             2.0
# 406  unneccessary legal process slow work order get...             5.0
# 177                    good companyadvice managementna             5.0
# 191  ltant singaporerecommendceo approvalbusiness o...             5.0
# 302              busy work dayadvice managementholiday             5.0
#
#      review_year
# 305         2020
# 125         2021
# 158         2021
# 447         2014
# 476         2022
# 314         2020
# 406         2017
# 177         2021
# 191         2021
# 302         2020

# %%
tencent_df.sample(10)
# Out:
#                  employee_title             location  \
# 415           Corporate Culture  Shenzhen, Guangdong
# 81           Front End Engineer  Shenzhen, Guangdong
# 347           Frontend Engineer  Shenzhen, Guangdong
# 274                 DataAnalyst  Shenzhen, Guangdong
# 250                   Anonymous  Shenzhen, Guangdong
# 375          Software Developer   Shanghai, Shanghai
# 455   Machine Learning Engineer     Beijing, Beijing
# 133               Web Developer   Shanghai, Shanghai
# 432           Software Engineer  Shenzhen, Guangdong
# 40                    Anonymous  Shenzhen, Guangdong
#
#                      review_title  \
# 415                  Good company
# 81                           nice
# 347      Frontend Engineer Review
# 274                   pretty good
# 250  A good company just in China
# 375                             1
# 455                          Good
# 133             wonderful company
# 432                        hahaha
# 40               Account Director
#
#                                                   pros  \
# 415                         strive achieve good caring
# 81           big platform well welfare lead technology
# 347             good work life balance chinese company
# 274                     work life balance benefit good
# 250                          china tencent good choice
# 375                              good benefit employee
# 455          good wlb great environment good colleague
# 133                     wonderful people decent salary
# 432  professionalism responsibility team mean thing...
# 40                          big internet company china
#
#                                   cons  rating_overall  review_year  \
# 415                     ot culture bit             5.0         2021
# 81        busy lack promotion lack wlb             5.0         2022
# 347          don t like culture minute             4.0         2021
# 274             employee large company             5.0         2021
# 250       work life balance work china             4.0         2021
# 375        open culture overally speak             1.0         2021
# 455          low pay high workload etc             4.0         2021
# 133                     work hour long             5.0         2022
# 432  insufficient innovation proactive             5.0         2021
# 40          b business little weakness             4.0         2019
#
#                                                   test
# 415                    (strive, achieve, good, caring)
# 81    (big, platform, well, welfare, lead, technology)
# 347      (good, work, life, balance, chinese, company)
# 274               (work, life, balance, benefit, good)
# 250                     (china, tencent, good, choice)
# 375                          (good, benefit, employee)
# 455   (good, wlb, great, environment, good, colleague)
# 133                (wonderful, people, decent, salary)
# 432  (professionalism, responsibility, team, mean, ...
# 40                     (big, internet, company, china)

# %% [markdown]
# ### Analysis of pros and cons

# %%
pd.set_option('display.max_colwidth', 999)

# %%
'''since the data has already been split between pros and cons. we will use them separately to see what are the top 10 keywords
of pros and cons'''

'''Tencent pros & cons'''
pros_tencent = tencent_df['pros']
pros_tencent = str(pros_tencent)

cons_tencent = tencent_df['cons']
cons_tencent = str(cons_tencent)

'''Google pros & cons'''
pros_google = google_df['pros']
pros_google = str(pros_google)

cons_google = google_df['cons']
cons_google = str(cons_google)

# %%
'''cleaning the data after combining them for a final overview of the common words'''
def clean_2(text):
    
    # remove "/n"
    pattern5 = re.compile(r'\n\d+')
    text = pattern5.sub(r'',text)
    # remove irrelevant character such as numbers and punctuation
    pattern6 = re.compile(r'[^a-zA-Z0-9]')
    text = pattern6.sub(r' ',text)
    # remove extra whitespaces
    pattern7= re.compile(r'^\s*|\s\s*')
    text = pattern7.sub(r' ', text).strip()
    # text to all lower case
    text = text.lower()
    
    return text

# %%
# eg of how the text looks like after combining all the text into a list

cons_tencent
# Out:
# '0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           communication mainland china require\n1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               work balance chinese english env\n2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                minimum plan maximum firefighting project communication email messenger alert 10 second impossible focus want want messy internal tool chinese counterpart don t respect time assume work hour advice managementsingapore china\n3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      cfo say win t layoff industry downtime year end sharing lay ton ton people second quarter year group leader narcissistic disorganized promote senior management treat employee like robot\n4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             need international\n5                                                                                                                                                                                                                                     ...

# %%
'''due to the formatting examples shown above, we have to split the text data into words'''
# Out:
# 'due to the formatting examples shown above, we have to split the text data into words'

# %%
'''splitting the list into words'''

# tencent
pros_tencent = pros_tencent.split()
cons_tencent = cons_tencent.split()

# google
pros_google = pros_google.split()
cons_google = cons_google.split()

# %%
'''Counting the common words'''

# tencent
tencent_pros = Counter(pros_tencent)
tencent_cons = Counter(cons_tencent)

# google
google_pros = Counter(pros_google)
google_cons = Counter(cons_google)

# %%
top10pros_tencent = pd.DataFrame(tencent_pros.most_common(10), columns=['words','counts'])
top10cons_tencent = pd.DataFrame(tencent_cons.most_common(10), columns=['words','counts'])

top10pros_google = pd.DataFrame(google_pros.most_common(10), columns=['words','counts'])
top10cons_google = pd.DataFrame(google_cons.most_common(10), columns=['words','counts'])

# %%
top10pros_tencent
# Out:
#          words  counts
# 0         good     285
# 1      company     114
# 2         work     107
# 3       salary      82
# 4        great      70
# 5      culture      66
# 6         nice      64
# 7      benefit      62
# 8  environment      62
# 9          lot      45

# %%
top10cons_tencent
# Out:
#            words  counts
# 0           work     233
# 1           life      62
# 2        company      58
# 3           time      57
# 4  responsethank      53
# 5        balance      51
# 6           good      49
# 7           long      49
# 8       overtime      43
# 9           hour      40

# %%
top10pros_google
# Out:
#          words  counts
# 0         work     200
# 1         good     195
# 2        great     176
# 3      benefit     113
# 4       people     108
# 5      culture      95
# 6      company      72
# 7  environment      52
# 8         perk      45
# 9        place      42

# %%
top10cons_google
# Out:
#      words  counts
# 0     work     127
# 1  company      85
# 2   people      73
# 3   google      60
# 4     good      47
# 5      big      47
# 6      con      44
# 7     time      39
# 8     hard      37
# 9        s      37
