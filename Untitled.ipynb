# %%
# using the scraper provided by MatthewChatham

pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %run main.py --url "https://www.glassdoor.sg/Reviews/Tencent-Reviews-E38281.htm" --limit 400 -f tencent_reviews.csv
# Out:
# 2022-05-17 19:20:52,209 INFO 435    :main.py(12548) - Configuring browser
# 2022-05-17 19:20:52,209 INFO 435    :main.py(12548) - Configuring browser
# 2022-05-17 19:20:52,209 INFO 435    :main.py(12548) - Configuring browser
# 2022-05-17 19:20:52,209 INFO 435    :main.py(12548) - Configuring browser
# 2022-05-17 19:20:52,209 INFO 435    :main.py(12548) - Configuring browser
# 2022-05-17 19:20:52,209 INFO 435    :main.py(12548) - Configuring browser
# 2022-05-17 19:20:52,209 INFO 435    :main.py(12548) - Configuring browser
# 2022-05-17 19:20:52,209 INFO 435    :main.py(12548) - Configuring browser
# 2022-05-17 19:20:52,209 INFO 435    :main.py(12548) - Configuring browser
# 2022-05-17 19:20:52,209 INFO 435    :main.py(12548) - Configuring browser
# 2022-05-17 19:20:52,209 INFO 435    :main.py(12548) - Configuring browser
# 2022-05-17 19:20:52,209 INFO 435    :main.py(12548) - Configuring browser
# 2022-05-17 19:20:52,209 INFO 435    :main.py(12548) - Configuring browser
# ...
